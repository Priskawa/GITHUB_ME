# %% [markdown]
# # MAZ Diplomarbeit 2019 #
#
#
#
# ### Artenvielfalt in der Schweiz ###
# # Trügerische Idylle #

# %% [markdown]
# ### Ausgangsthese: ###
# Die Biodiversität in unserem Land ist weit stärker gefährdet, als Herr und Frau Schweizer glauben. Trotz oftmals intakt scheinender Natur, sind viel mehr Ökosysteme und Tiere bedroht, als die Bilder unserer heilen Schweizer (Natur-)Welt uns glauben lassen.

# %% [markdown]
# ### Aufwand/Ertrag (Spider-Check): ###
#
# • Reichweite ***
#
# • Journalistischer Impact **
#
# • Innovation **
#
# • Tiefe des Inhalts ****
#
# • Kooperationspotenzial ***
#
# • Know-How-Aufbau 8* (Acht Sterne - nur deswegen lohnt sich diese Arbeit schon ; )))

# %% [markdown]
# ### Knackpunkt: ###
# Die Daten sind beim BAFU verstreut vorhanden als Excel, Text-pdf und Bild-pdf. Jedoch sind die letzten vom BAFU veröffentlichten “Zusammenfassungen” nicht mehr aktuell. Deswegen lohnt sich das detaillierte einlesen, zusammentragen und aufbereiten der Dateien. Ebenso um einzelne Tiergruppen (z.B. Libellen, Fliegen, Wasserkäfer, …, etc zu “Insekten”) zusammenfassen zu können.
# Mit der ersten publizierten “Liste der bedrohten Lebensräume” kann ich so ein Gesamtpaket zum Zustand der Biodiversität in der Schweiz schnüren. Und natürlich zeichnerisch darstellen...

# %% [markdown]
# ### Rechercheplan: ###
#
# **Thesencheck:** Zusammentragen aller vom BAFU über die Jahre publizierten roten Listen, Auswertung der Daten nach Tiergruppe, Tierart und Gefährdungsgrad (nach erfassten Tierarten). Quasi erstellen einer Datenbank, die mit jedem Erscheinen einer aktuellen Liste upgedatet werden kann.
#
# **Vergleich:** mit den Schlüsseldaten nach Tiergruppen der IUCN. (Wie steht die Schweiz da im internationalen Vergleich?)
#
# **Resümee:** Kurzes Interview mit René Amstutz
#
# **Fachperson: René Amstutz, Projektleiter Biotope und Arten, Pro Natura, Franziska Rosenmund, Pressesprecherin, Pro Natura**
#
# **Anmerkung:** Ich wollte zuerst die Flora in die Geschichte mit einbeziehen, aber das ganze Paket wäre too much geworden und ein einfacher Erzählstrang kompliziert. Also habe ich nachdem ich mit den Visualisierungen und dem Konzept fürs Longform begonnen habe mich vom Kapitel “Flora” getrennt. Ein andermal…

# %% [markdown]
# ## Arbeitsablauf: ##
#
# - einlesen in die Story
# - Recherche der einzelnen Datensätze (BAFU, IUCN)
#
# - einlesen csv, Übersicht verschaffen, visualisieren mit Pandas
# - einlesen der pdf in tabula, bereinigen, einlesen in Jupyter, Überblick, Visu mit Pandas
# - zusammentragen der Tierarten in Tiergruppen (Systematik)
# - splitten von Tiergruppen in Tierfamilen
# - einzelne Files gleich strukturieren um einen Overview zusammenstellen zu können
# - Nachkontrolle der Ergebnisse mit Hilfe der Quellen
#
# - Pro Natura an Bord holen, fachliche Einschätzung
# - Grobkonzept Longform
# - Zeichnen der einzelnen Elemente
# - Finetuning Konzept Longform, Storyboard, Briefing Kollegin
# - Texte schreiben, Redigier-Hilfe vom Kollegen holen
#
# - Pro Natura an Bord, fachliche Stellungnahme, Fachlicher Fakten-Check
#
# - Korrektorat, Produktion
# - Publikation

# %% [markdown]
# ## Code und Dokumentation: ##
#
# Viele einzelne Files, mit ähnlichen Codes, um alles in Form zu bringen...
# **Ausdokumentiert sind folgende Jupyter-Files:**
#
# **• 001_einlesen_csv_amphibien**
#
# **• 002_einlesen_tabulacsv_vögel**
#
# **• 003_insekten_zusammenfassen**
#
# **• 004_overview_schweiz_tiere**
#
# **• 004_IUCN_overview**

# %% [markdown]
# ## Visuelle Umsetzung, Konzeptionierung Longform, Publikation: ##
#
# Erstellen eines Storyboards in Indesign. Briefing meiner Kollegin Janine Gygax, die bei uns die Longforms programmiert, wie ich den Inhalt gestaltet haben möchte.
# Janine Gygax hat das Gerüst für meine Online-Story gebaut. Merci Janine : )
#
# **Text schreiben:**
# Nicht einfach zeichnen, da das Ganze auf Blick.ch erscheinen soll, auch viel mehr schreiben, als ich das sonst gewohnt bin. Habe ich gemacht, meinen ersten Text dann aber von Simon Huwiler, einem Journalisten, redigieren lassen. Text also in Zusammenarbeit mit Simon Huwiler. Dankeschön Simon : )
#
# **Publikation:**
# (Die “echte” Publikation ist für Mitte/Ende März geplant- zum Start in den Frühling. Dieser Link geht direkt auf unseren internen Server, und das Longform wird noch kleines, technisches finetuning erfahren.)

# %% [markdown]
# https://www.blick.ch/storytelling/2019/priska/index.html

# %% [markdown]
# Fragen und Kontakt: priska.wallimann@ringier.ch

# %% [markdown]
# ### Ein kleiner Einstieg... ###

# %%
from IPython.display import Image
Image(filename='Swiss_Landscape.png')
