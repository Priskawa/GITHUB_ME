# %% [markdown]
# # MAZ Diplomarbeit - Biodiversität in der Schweiz#

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("01_source/xls_ch/eintags_stein_koecherfliegenarten_ch.csv")

# %%
df.head()
# Out:
#      GROUP          ORDER      FAMILY       GENUS     SPECIES  \
# 0  Insecta  Ephemeroptera    Baetidae  Acentrella     sinaica
# 1  Insecta  Ephemeroptera    Baetidae   Alainites     muticus
# 2  Insecta  Ephemeroptera  Ameletidae    Ameletus  inopinatus
# 3  Insecta  Ephemeroptera    Baetidae      Baetis     alpinus
# 4  Insecta  Ephemeroptera    Baetidae      Baetis   buceratus
#
#                       Scientific name Deutscher Name CAT            Criteria  \
# 0   Acentrella sinaica Bogoescu, 1931              -  CR   B2a, B2b (ii,iii)
# 1  Alainites muticus (Linnaeus, 1758)              -  LC                 NaN
# 2     Ameletus inopinatus Eaton, 1887              -  CR  B2a, B2b (iii, iv)
# 3       Baetis alpinus (Pictet, 1843)              -  LC                 NaN
# 4        Baetis buceratus Eaton, 1870              -  VU            B2b (iv)
#
#                             Bemerkungen
# 0  Sehr beschränktes Verbreitungsgebiet
# 1                                   NaN
# 2            Nur 2 Populationen bekannt
# 3                                   NaN
# 4                                   NaN

# %%
len (df)
# Out:
# 507

# %%
df.shape
# Out:
# (507, 10)

# %%
df["CAT"].value_counts()
# Out:
# LC    186
# VU     81
# NT     71
# EN     68
# CR     51
# RE     27
# DD     15
# NE      8
# Name: CAT, dtype: int64

# %%
df.head(1)
# Out:
#      GROUP          ORDER    FAMILY       GENUS  SPECIES  \
# 0  Insecta  Ephemeroptera  Baetidae  Acentrella  sinaica
#
#                      Scientific name Deutscher Name CAT           Criteria  \
# 0  Acentrella sinaica Bogoescu, 1931              -  CR  B2a, B2b (ii,iii)
#
#                             Bemerkungen
# 0  Sehr beschränktes Verbreitungsgebiet

# %%
df.rename(columns={"GROUP":"group","ORDER":"order","FAMILY":"family","GENUS":"genus","SPECIES":"species","Scientific name":"sc name","Deutscher Name":"dt name","CAT":"cat", "Criteria": "criteria", "Bemerkungen":"bemerkungen"},inplace=True)

# %%
df
# Out:
#        group          order           family             genus  \
# 0    Insecta  Ephemeroptera         Baetidae        Acentrella
# 1    Insecta  Ephemeroptera         Baetidae         Alainites
# 2    Insecta  Ephemeroptera       Ameletidae          Ameletus
# 3    Insecta  Ephemeroptera         Baetidae            Baetis
# 4    Insecta  Ephemeroptera         Baetidae            Baetis
# 5    Insecta  Ephemeroptera         Baetidae            Baetis
# 6    Insecta  Ephemeroptera         Baetidae            Baetis
# 7    Insecta  Ephemeroptera         Baetidae            Baetis
# 8    Insecta  Ephemeroptera         Baetidae            Baetis
# 9    Insecta  Ephemeroptera         Baetidae            Baetis
# 10   Insecta  Ephemeroptera         Baetidae            Baetis
# 11   Insecta  Ephemeroptera         Baetidae            Baetis
# 12   Insecta  Ephemeroptera         Baetidae            Baetis
# 13   Insecta  Ephemeroptera         Baetidae            Baetis
# 14   Insecta  Ephemeroptera         Baetidae            Baetis
# 15   Insecta  Ephemeroptera         Caenidae            Caenis
# 16   Insecta  Ephemeroptera         Caenidae            Caenis
# 17   Insecta  Ephemeroptera         Caenidae            Caenis
# 18   Insecta  Ephemeroptera         Caenidae            Caenis
# 19   Insecta  Ephemeroptera         Caenidae            Caenis
# 20   Insecta  Ephemeroptera         Caenidae            Caenis
# 21   Insecta  Ephemeroptera         Caenidae            Caenis
# 22   Insecta  Ephemeroptera         Caenidae            Caenis
# 23   Insecta  Ephemeroptera         Baetidae      Centroptilum
# 24   Insecta  Ephemeroptera  Leptophlebiidae       Choroterpes
# 25   Insecta  Ephemeroptera         Baetidae            Cloeon
# 26   Insecta  Ephemeroptera         Baetidae            Cloeon
# 27   Insecta  Ephemeroptera    Heptageniidae        Ecdyonurus
# 28   Insecta  Ephemeroptera    Heptageniidae        Ecdyonurus
# 29   Insecta  Ephemeroptera    Heptageniidae        Ecdyonurus
# ..       ...            ...              ...               ...
# 477  Insecta    Trichoptera    Hydroptilidae         Stactobia
# 478  Insecta    Trichoptera    Hydroptilidae         Stactobia
# 479  Insecta    Trichoptera    Hydroptilidae      Stactobiella
# 480  Insecta    Trichoptera    Limnephilidae       Stenophylax
# 481  Insecta    Trichoptera    Limnephilidae       Stenophylax
# 482  Insecta    Trichoptera    Limnephilidae       Stenophylax
# 483  Insecta    Trichoptera    Limnephilidae       Stenophylax
# 484  Insecta    Trichoptera  Glossosomatidae       Synagapetus
# 485  Insecta    Trichoptera  Glossosomatidae       Synagapetus
# 486  Insecta    Trichoptera    Psychomyiidae           Tinodes
# 487  Insecta    Trichoptera    Psychomyiidae           Tinodes
# 488  Insecta    Trichoptera    Psychomyiidae           Tinodes
# 489  Insecta    Trichoptera    Psychomyiidae           Tinodes
# 490  Insecta    Trichoptera    Psychomyiidae           Tinodes
# 491  Insecta    Trichoptera    Psychomyiidae           Tinodes
# 492  Insecta    Trichoptera    Psychomyiidae           Tinodes
# 493  Insecta    Trichoptera    Psychomyiidae           Tinodes
# 494  Insecta    Trichoptera    Psychomyiidae           Tinodes
# 495  Insecta    Trichoptera    Psychomyiidae           Tinodes
# 496  Insecta    Trichoptera    Psychomyiidae           Tinodes
# 497  Insecta    Trichoptera    Psychomyiidae           Tinodes
# 498  Insecta    Trichoptera     Leptoceridae        Triaenodes
# 499  Insecta    Trichoptera    Hydroptilidae  Tricholeiochiton
# 500  Insecta    Trichoptera     Phryganeidae      Trichostegia
# 501  Insecta    Trichoptera   Philopotamidae         Wormaldia
# 502  Insecta    Trichoptera   Philopotamidae         Wormaldia
# 503  Insecta    Trichoptera   Philopotamidae         Wormaldia
# 504  Insecta    Trichoptera   Philopotamidae         Wormaldia
# 505  Insecta    Trichoptera   Philopotamidae         Wormaldia
# 506  Insecta    Trichoptera   Philopotamidae         Wormaldia
#
#             species                                            sc name  \
# 0           sinaica                  Acentrella sinaica Bogoescu, 1931
# 1           muticus                 Alainites muticus (Linnaeus, 1758)
# 2        inopinatus                    Ameletus inopinatus Eaton, 1887
# 3           alpinus                      Baetis alpinus (Pictet, 1843)
# 4         buceratus                       Baetis buceratus Eaton, 1870
# 5          fuscatus                      Baetis fuscatus (Linné, 1761)
# 6        liebenauae               Baetis liebenauae Keffermüller, 1974
# 7           lutheri               Baetis lutheri Müller-Liebenau, 1967
# 8         melanonyx                    Baetis melanonyx (Pictet, 1843)
# 9       nubecularis                     Baetis nubecularis Eaton, 1898
# 10   pentaphlebodes                Baetis pentaphlebodes Ujhelyi, 1966
# 11          rhodani                      Baetis rhodani (Pictet, 1843)
# 12          scambus                         Baetis scambus Eaton, 1870
# 13      vardarensis                  Baetis vardarensis IKonomov, 1962
# 14           vernus                         Baetis vernus Curtis, 1834
# 15      beskidensis                      Caenis beskidensis Sowa, 1973
# 16          horaria                    Caenis horaria (Linnaeus, 1758)
# 17           lactea                   Caenis lactea (Burmeister, 1839)
# 18         luctuosa                 Caenis luctuosa (Burmeister, 1839)
# 19          macrura                      Caenis macrura Stephens, 1835
# 20          pusilla                         Caenis pusilla Navas, 1913
# 21        rivulorum                       Caenis rivulorum Eaton, 1884
# 22          robusta                         Caenis robusta Eaton, 1884
# 23         luteolum               Centroptilum luteolum (Müller, 1776)
# 24          picteti                    Choroterpes picteti Eaton, 1871
# 25         dipterum                      Cloeon dipterum (Linné, 1761)
# 26           simile                          Cloeon simile Eaton, 1870
# 27          alpinus    Ecdyonurus alpinus Hefti, Tomka, Zurwerra, 1987
# 28           dispar                   Ecdyonurus dispar (Curtis, 1834)
# 29       helveticus                Ecdyonurus helveticus (Eaton, 1885)
# ..              ...                                                ...
# 477         furcata                     Stactobia furcata Mosely, 1930
# 478         moselyi                    Stactobia moselyi Kimmins, 1949
# 479            risi                   Stactobiella risi (Felber, 1908)
# 480           mitis                  Stenophylax mitis McLachlan, 1875
# 481      mucronatus             Stenophylax mucronatus McLachlan, 1880
# 482       permistus              Stenophylax permistus McLachlan, 1895
# 483           vibex                   Stenophylax vibex (Curtis, 1834)
# 484        dubitans               Synagapetus dubitans McLachlan, 1879
# 485     iridipennis            Synagapetus iridipennis McLachlan, 1879
# 486        antonioi  Tinodes antonioi Botosaneanu & Taticchi-Vigano...
# 487       assimilis                  Tinodes assimilis McLachlan, 1865
# 488           dives                       Tinodes dives (Pictet, 1834)
# 489        luscinia                         Tinodes luscinia Ris, 1903
# 490     maclachlani                  Tinodes maclachlani Kimmins, 1966
# 491    maculicornis                Tinodes maculicornis (Pictet, 1834)
# 492      pallidulus                 Tinodes pallidulus McLachlan, 1878
# 493        rostocki                   Tinodes rostocki McLachlan, 1878
# 494          sylvia                           Tinodes sylvia Ris, 1903
# 495        unicolor                    Tinodes unicolor (Pictet, 1834)
# 496         waeneri                   Tinodes waeneri (Linnaeus, 1758)
# 497         zelleri                    Tinodes zelleri McLachlan, 1878
# 498         bicolor                  Triaenodes bicolor (Curtis, 1834)
# 499         fagesii           Tricholeiochiton fagesii (Guinard, 1879)
# 500           minor                  Trichostegia minor (Curtis, 1834)
# 501         copiosa                Wormaldia copiosa (McLachlan, 1868)
# 502         mediana                  Wormaldia mediana McLachlan, 1878
# 503     occipitalis               Wormaldia occipitalis (Pictet, 1834)
# 504           pulla                  Wormaldia pulla (McLachlan, 1878)
# 505        subnigra                 Wormaldia subnigra McLachlan, 1865
# 506       variegata      Wormaldia variegata maclachlani Kimmins, 1953
#
#     dt name cat                criteria  \
# 0         -  CR       B2a, B2b (ii,iii)
# 1         -  LC                     NaN
# 2         -  CR      B2a, B2b (iii, iv)
# 3         -  LC                     NaN
# 4         -  VU                B2b (iv)
# 5         -  LC                     NaN
# 6         -  VU           B2a, B2b (iv)
# 7         -  LC                     NaN
# 8         -  NT                B2b (ii)
# 9         -  VU           B2b (iii, iv)
# 10        -  VU                     B2a
# 11        -  LC                     NaN
# 12        -  LC                     NaN
# 13        -  NT                B2b (iv)
# 14        -  LC                     NaN
# 15        -  VU       B2b (ii, iii, iv)
# 16        -  LC                     NaN
# 17        -  VU                B2b (iv)
# 18        -  LC                     NaN
# 19        -  LC                     NaN
# 20        -  CR  B2a, B2b (ii), B2c(ii)
# 21        -  EN       B2a, B2b (ii, iv)
# 22        -  NT               B2b (iii)
# 23        -  LC                     NaN
# 24        -  EN   B2a, B2b (ii, iii,iv)
# 25        -  LC                     NaN
# 26        -  LC                     NaN
# 27        -  NT                 B2b (i)
# 28        -  VU           B2b (ii, iii)
# 29        -  LC                     NaN
# ..      ...  ..                     ...
# 477       -  DD                     NaN
# 478       -  EN         B2a, b(i,ii,iv)
# 479       -  RE                     NaN
# 480       -  LC                     NaN
# 481       -  EN     B2a, b(i,ii,iii,iv)
# 482       -  LC                     NaN
# 483       -  NT                     NaN
# 484       -  NT                     NaN
# 485       -  VU         B2a, b(ii, iii)
# 486       -  EN             B2a, b(iii)
# 487       -  DD              B2a,b(iii)
# 488       -  LC                     NaN
# 489       -  EN             B2a, b(iii)
# 490       -  VU             B2a, b(iii)
# 491       -  VU             B2a, b(iii)
# 492       -  EN    B2a, b(i, ii,iii,iv)
# 493       -  NT                     NaN
# 494       -  CR     B2a, b(i,ii,iii,iv)
# 495       -  LC                     NaN
# 496       -  LC                     NaN
# 497       -  VU            B2a, b( iii)
# 498       -  CR     B2a, b(i,ii,iii,iv)
# 499       -  CR     B2a, b(i,ii,iii,iv)
# 500       -  VU             B2a, b(iii)
# 501       -  LC                     NaN
# 502       -  CR     B2a, b(i,ii,iii,iv)
# 503       -  LC                     NaN
# 504       -  EN    B2a, b(i,ii,iiii,iv)
# 505       -  RE                     NaN
# 506       -  VU             B2a, b(iii)
#
#                                            bemerkungen
# 0                 Sehr beschränktes Verbreitungsgebiet
# 1                                                  NaN
# 2                           Nur 2 Populationen bekannt
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                         Jura-Endemit
# 10          Erstnachweis 2002; 3 bekannte Populationen
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                        Rezente Abnahme nachgewiesen
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 477                             einziger Nachweis 1991
# 478             Quellen, ausschliesslich hygropterisch
# 479                  letzter Nachweis 1908, Quellbäche
# 480                                                NaN
# 481                                                NaN
# 482                                                NaN
# 483                                                NaN
# 484                                                NaN
# 485                                            Quellen
# 486                                             Tessin
# 487                 Quellen, Quellbäche, hygropetrisch
# 488                                                NaN
# 489                                             Tessin
# 490                            Quellbäche, Epirhithral
# 491  Stehende und fliessende Gewässer, auch hygrope...
# 492                              Kleine Bäche, Giessen
# 493                                                NaN
# 494                                    Quellen, Tessin
# 495                                                NaN
# 496                                                NaN
# 497                             Quellen, hygropetrisch
# 498                Moore, pflanzenreiche Stillgewässer
# 499                               Moore, Stillgewässer
# 500                     Moore, auch temporäre Gewässer
# 501                                                NaN
# 502                                      Bäche, Tessin
# 503                                                NaN
# 504                                                NaN
# 505           Letzter Nachweis 1900, Flüsse Mittelland
# 506  Tessin, in der Schweiz die Unterart W. v. macl...
#
# [507 rows x 10 columns]

# %%
df.pop("criteria")
df.pop("genus")
df.pop("species")
# Out:
# 0             sinaica
# 1             muticus
# 2          inopinatus
# 3             alpinus
# 4           buceratus
# 5            fuscatus
# 6          liebenauae
# 7             lutheri
# 8           melanonyx
# 9         nubecularis
# 10     pentaphlebodes
# 11            rhodani
# 12            scambus
# 13        vardarensis
# 14             vernus
# 15        beskidensis
# 16            horaria
# 17             lactea
# 18           luctuosa
# 19            macrura
# 20            pusilla
# 21          rivulorum
# 22            robusta
# 23           luteolum
# 24            picteti
# 25           dipterum
# 26             simile
# 27            alpinus
# 28             dispar
# 29         helveticus
#             ...
# 477           furcata
# 478           moselyi
# 479              risi
# 480             mitis
# 481        mucronatus
# 482         permistus
# 483             vibex
# 484          dubitans
# 485       iridipennis
# 486          antonioi
# 487         assimilis
# 488             dives
# 489          luscinia
# 490       maclachlani
# 491      maculicornis
# 492        pallidulus
# 493          rostocki
# 494            sylvia
# 495          unicolor
# 496           waeneri
# 497           zelleri
# 498           bicolor
# 499           fagesii
# 500             minor
# 501           copiosa
# 502           mediana
# 503       occipitalis
# 504             pulla
# 505          subnigra
# 506         variegata
# Name: species, Length: 507, dtype: object

# %%
df
# Out:
#        group          order           family  \
# 0    Insecta  Ephemeroptera         Baetidae
# 1    Insecta  Ephemeroptera         Baetidae
# 2    Insecta  Ephemeroptera       Ameletidae
# 3    Insecta  Ephemeroptera         Baetidae
# 4    Insecta  Ephemeroptera         Baetidae
# 5    Insecta  Ephemeroptera         Baetidae
# 6    Insecta  Ephemeroptera         Baetidae
# 7    Insecta  Ephemeroptera         Baetidae
# 8    Insecta  Ephemeroptera         Baetidae
# 9    Insecta  Ephemeroptera         Baetidae
# 10   Insecta  Ephemeroptera         Baetidae
# 11   Insecta  Ephemeroptera         Baetidae
# 12   Insecta  Ephemeroptera         Baetidae
# 13   Insecta  Ephemeroptera         Baetidae
# 14   Insecta  Ephemeroptera         Baetidae
# 15   Insecta  Ephemeroptera         Caenidae
# 16   Insecta  Ephemeroptera         Caenidae
# 17   Insecta  Ephemeroptera         Caenidae
# 18   Insecta  Ephemeroptera         Caenidae
# 19   Insecta  Ephemeroptera         Caenidae
# 20   Insecta  Ephemeroptera         Caenidae
# 21   Insecta  Ephemeroptera         Caenidae
# 22   Insecta  Ephemeroptera         Caenidae
# 23   Insecta  Ephemeroptera         Baetidae
# 24   Insecta  Ephemeroptera  Leptophlebiidae
# 25   Insecta  Ephemeroptera         Baetidae
# 26   Insecta  Ephemeroptera         Baetidae
# 27   Insecta  Ephemeroptera    Heptageniidae
# 28   Insecta  Ephemeroptera    Heptageniidae
# 29   Insecta  Ephemeroptera    Heptageniidae
# ..       ...            ...              ...
# 477  Insecta    Trichoptera    Hydroptilidae
# 478  Insecta    Trichoptera    Hydroptilidae
# 479  Insecta    Trichoptera    Hydroptilidae
# 480  Insecta    Trichoptera    Limnephilidae
# 481  Insecta    Trichoptera    Limnephilidae
# 482  Insecta    Trichoptera    Limnephilidae
# 483  Insecta    Trichoptera    Limnephilidae
# 484  Insecta    Trichoptera  Glossosomatidae
# 485  Insecta    Trichoptera  Glossosomatidae
# 486  Insecta    Trichoptera    Psychomyiidae
# 487  Insecta    Trichoptera    Psychomyiidae
# 488  Insecta    Trichoptera    Psychomyiidae
# 489  Insecta    Trichoptera    Psychomyiidae
# 490  Insecta    Trichoptera    Psychomyiidae
# 491  Insecta    Trichoptera    Psychomyiidae
# 492  Insecta    Trichoptera    Psychomyiidae
# 493  Insecta    Trichoptera    Psychomyiidae
# 494  Insecta    Trichoptera    Psychomyiidae
# 495  Insecta    Trichoptera    Psychomyiidae
# 496  Insecta    Trichoptera    Psychomyiidae
# 497  Insecta    Trichoptera    Psychomyiidae
# 498  Insecta    Trichoptera     Leptoceridae
# 499  Insecta    Trichoptera    Hydroptilidae
# 500  Insecta    Trichoptera     Phryganeidae
# 501  Insecta    Trichoptera   Philopotamidae
# 502  Insecta    Trichoptera   Philopotamidae
# 503  Insecta    Trichoptera   Philopotamidae
# 504  Insecta    Trichoptera   Philopotamidae
# 505  Insecta    Trichoptera   Philopotamidae
# 506  Insecta    Trichoptera   Philopotamidae
#
#                                                sc name dt name cat  \
# 0                    Acentrella sinaica Bogoescu, 1931       -  CR
# 1                   Alainites muticus (Linnaeus, 1758)       -  LC
# 2                      Ameletus inopinatus Eaton, 1887       -  CR
# 3                        Baetis alpinus (Pictet, 1843)       -  LC
# 4                         Baetis buceratus Eaton, 1870       -  VU
# 5                        Baetis fuscatus (Linné, 1761)       -  LC
# 6                 Baetis liebenauae Keffermüller, 1974       -  VU
# 7                 Baetis lutheri Müller-Liebenau, 1967       -  LC
# 8                      Baetis melanonyx (Pictet, 1843)       -  NT
# 9                       Baetis nubecularis Eaton, 1898       -  VU
# 10                 Baetis pentaphlebodes Ujhelyi, 1966       -  VU
# 11                       Baetis rhodani (Pictet, 1843)       -  LC
# 12                          Baetis scambus Eaton, 1870       -  LC
# 13                   Baetis vardarensis IKonomov, 1962       -  NT
# 14                          Baetis vernus Curtis, 1834       -  LC
# 15                       Caenis beskidensis Sowa, 1973       -  VU
# 16                     Caenis horaria (Linnaeus, 1758)       -  LC
# 17                    Caenis lactea (Burmeister, 1839)       -  VU
# 18                  Caenis luctuosa (Burmeister, 1839)       -  LC
# 19                       Caenis macrura Stephens, 1835       -  LC
# 20                          Caenis pusilla Navas, 1913       -  CR
# 21                        Caenis rivulorum Eaton, 1884       -  EN
# 22                          Caenis robusta Eaton, 1884       -  NT
# 23                Centroptilum luteolum (Müller, 1776)       -  LC
# 24                     Choroterpes picteti Eaton, 1871       -  EN
# 25                       Cloeon dipterum (Linné, 1761)       -  LC
# 26                           Cloeon simile Eaton, 1870       -  LC
# 27     Ecdyonurus alpinus Hefti, Tomka, Zurwerra, 1987       -  NT
# 28                    Ecdyonurus dispar (Curtis, 1834)       -  VU
# 29                 Ecdyonurus helveticus (Eaton, 1885)       -  LC
# ..                                                 ...     ...  ..
# 477                     Stactobia furcata Mosely, 1930       -  DD
# 478                    Stactobia moselyi Kimmins, 1949       -  EN
# 479                   Stactobiella risi (Felber, 1908)       -  RE
# 480                  Stenophylax mitis McLachlan, 1875       -  LC
# 481             Stenophylax mucronatus McLachlan, 1880       -  EN
# 482              Stenophylax permistus McLachlan, 1895       -  LC
# 483                   Stenophylax vibex (Curtis, 1834)       -  NT
# 484               Synagapetus dubitans McLachlan, 1879       -  NT
# 485            Synagapetus iridipennis McLachlan, 1879       -  VU
# 486  Tinodes antonioi Botosaneanu & Taticchi-Vigano...       -  EN
# 487                  Tinodes assimilis McLachlan, 1865       -  DD
# 488                       Tinodes dives (Pictet, 1834)       -  LC
# 489                         Tinodes luscinia Ris, 1903       -  EN
# 490                  Tinodes maclachlani Kimmins, 1966       -  VU
# 491                Tinodes maculicornis (Pictet, 1834)       -  VU
# 492                 Tinodes pallidulus McLachlan, 1878       -  EN
# 493                   Tinodes rostocki McLachlan, 1878       -  NT
# 494                           Tinodes sylvia Ris, 1903       -  CR
# 495                    Tinodes unicolor (Pictet, 1834)       -  LC
# 496                   Tinodes waeneri (Linnaeus, 1758)       -  LC
# 497                    Tinodes zelleri McLachlan, 1878       -  VU
# 498                  Triaenodes bicolor (Curtis, 1834)       -  CR
# 499           Tricholeiochiton fagesii (Guinard, 1879)       -  CR
# 500                  Trichostegia minor (Curtis, 1834)       -  VU
# 501                Wormaldia copiosa (McLachlan, 1868)       -  LC
# 502                  Wormaldia mediana McLachlan, 1878       -  CR
# 503               Wormaldia occipitalis (Pictet, 1834)       -  LC
# 504                  Wormaldia pulla (McLachlan, 1878)       -  EN
# 505                 Wormaldia subnigra McLachlan, 1865       -  RE
# 506      Wormaldia variegata maclachlani Kimmins, 1953       -  VU
#
#                                            bemerkungen
# 0                 Sehr beschränktes Verbreitungsgebiet
# 1                                                  NaN
# 2                           Nur 2 Populationen bekannt
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                         Jura-Endemit
# 10          Erstnachweis 2002; 3 bekannte Populationen
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                        Rezente Abnahme nachgewiesen
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 477                             einziger Nachweis 1991
# 478             Quellen, ausschliesslich hygropterisch
# 479                  letzter Nachweis 1908, Quellbäche
# 480                                                NaN
# 481                                                NaN
# 482                                                NaN
# 483                                                NaN
# 484                                                NaN
# 485                                            Quellen
# 486                                             Tessin
# 487                 Quellen, Quellbäche, hygropetrisch
# 488                                                NaN
# 489                                             Tessin
# 490                            Quellbäche, Epirhithral
# 491  Stehende und fliessende Gewässer, auch hygrope...
# 492                              Kleine Bäche, Giessen
# 493                                                NaN
# 494                                    Quellen, Tessin
# 495                                                NaN
# 496                                                NaN
# 497                             Quellen, hygropetrisch
# 498                Moore, pflanzenreiche Stillgewässer
# 499                               Moore, Stillgewässer
# 500                     Moore, auch temporäre Gewässer
# 501                                                NaN
# 502                                      Bäche, Tessin
# 503                                                NaN
# 504                                                NaN
# 505           Letzter Nachweis 1900, Flüsse Mittelland
# 506  Tessin, in der Schweiz die Unterart W. v. macl...
#
# [507 rows x 7 columns]

# %%
df['einteilung'] = 'Insekten'
df['untergruppe'] = 'Eintags,-Stein-,Köcherfliegen'

# %%
df.head(5)
# Out:
#      group          order      family                             sc name  \
# 0  Insecta  Ephemeroptera    Baetidae   Acentrella sinaica Bogoescu, 1931
# 1  Insecta  Ephemeroptera    Baetidae  Alainites muticus (Linnaeus, 1758)
# 2  Insecta  Ephemeroptera  Ameletidae     Ameletus inopinatus Eaton, 1887
# 3  Insecta  Ephemeroptera    Baetidae       Baetis alpinus (Pictet, 1843)
# 4  Insecta  Ephemeroptera    Baetidae        Baetis buceratus Eaton, 1870
#
#   dt name cat                           bemerkungen einteilung  \
# 0       -  CR  Sehr beschränktes Verbreitungsgebiet   Insekten
# 1       -  LC                                   NaN   Insekten
# 2       -  CR            Nur 2 Populationen bekannt   Insekten
# 3       -  LC                                   NaN   Insekten
# 4       -  VU                                   NaN   Insekten
#
#                      untergruppe
# 0  Eintags,-Stein-,Köcherfliegen
# 1  Eintags,-Stein-,Köcherfliegen
# 2  Eintags,-Stein-,Köcherfliegen
# 3  Eintags,-Stein-,Köcherfliegen
# 4  Eintags,-Stein-,Köcherfliegen

# %%
df["cat"].value_counts()
# Out:
# LC    186
# VU     81
# NT     71
# EN     68
# CR     51
# RE     27
# DD     15
# NE      8
# Name: cat, dtype: int64

# %%
values = [0, 27, 51, 68, 81, 71, 186, 15, 8]
colors = ['r', 'r', 'r', 'r', 'r', 'g', "g", "grey", "grey"]
labels = [
    'EX: ausgestorben', 'RE: CH ausgestorben',
    'CR: v. aussterben bedroht', 'EN: stark gefährdet', 
    'VU: verletzlich',"NT: potenziell gef.",
    "LC: nicht gef.","DD: ungen. Daten","NE: nicht beurteilt"]


fig1, ax1 = plt.subplots(figsize=(7, 6))
fig1.subplots_adjust(0.3,0,1,1)
plt.pie(values, colors=colors, labels= values, counterclock=False,startangle=90)
plt.title('Gefährdung Eintags-, Stein- u. Köcherfliegen, 507 Arten')

total = sum(values)
plt.legend(
    loc='upper left',
    labels=['%s, %1.1f%%' % (
        l, (float(s) / total) * 100) for l, s in zip(labels, values)],
    
    bbox_to_anchor=(1.0, 0.5),
    bbox_transform=fig1.transFigure
)
plt.show()
