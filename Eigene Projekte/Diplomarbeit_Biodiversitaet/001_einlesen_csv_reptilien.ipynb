# %% [markdown]
# # MAZ Diplomarbeit - Biodiversität in der Schweiz#

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("01_source/xls_ch/reptilien_ch.csv")

# %%
df.head()
# Out:
#        classe       ordre     famille     genre       espèce    sous-espèce  \
# 0  Sauropsida  Cheloniens    Emydidae      Emys  orbicularis    orbicularis
# 1  Sauropsida    Squamata  Lacertidae   Lacerta       agilis         agilis
# 2  Sauropsida    Squamata  Lacertidae   Lacerta    bilineata      bilineata
# 3  Sauropsida    Squamata  Lacertidae  Podarcis      muralis        muralis
# 4  Sauropsida    Squamata  Lacertidae  Podarcis      muralis  maculiventris
#
#                                  D statut CH           critères  \
# 0                 Sumpfschildkröte        CR      B2a, B2b(iii)
# 1                     Zauneidechse        VU   B2a, B2b(ii,iii)
# 2                  Smaragdeidechse        VU  B2a, B2b(iii, iv)
# 3          Mauereidechse (muralis)        LC                NaN
# 4  Mauereidechse\n (maculiventris)        LC                NaN
#
#                                   Bemerkungen
# 0                                         NaN
# 1                         Genereller Rückgang
# 2  Starker Rückgang in den Kantonen VD und GE
# 3        Gefährdet in den Kantonen AG, SH, ZH
# 4                                         NaN

# %%
len (df)
# Out:
# 19

# %%
df.shape
# Out:
# (19, 10)

# %%
df["statut CH"].value_counts()
# Out:
# EN    7
# VU    5
# LC    4
# CR    3
# Name: statut CH, dtype: int64

# %%
df.rename(columns={"classe":"group","ordre": "order","famille":"family","genre":"genus","espèce":"species","D":"dt name","statut CH":"cat","critères":"criteria", "Bemerkungen":"bemerkungen"},inplace=True)

# %%
df
# Out:
#          group       order      family      genus       species  \
# 0   Sauropsida  Cheloniens    Emydidae       Emys   orbicularis
# 1   Sauropsida    Squamata  Lacertidae    Lacerta        agilis
# 2   Sauropsida    Squamata  Lacertidae    Lacerta     bilineata
# 3   Sauropsida    Squamata  Lacertidae   Podarcis       muralis
# 4   Sauropsida    Squamata  Lacertidae   Podarcis       muralis
# 5   Sauropsida    Squamata  Lacertidae    Zootoca      vivipara
# 6   Sauropsida    Squamata    Anguidae     Anguis      fragilis
# 7   Sauropsida    Squamata  Colubridae  Hierophis  viridiflavus
# 8   Sauropsida    Squamata  Colubridae    Zamenis   longissimus
# 9   Sauropsida    Squamata  Colubridae  Coronella     austriaca
# 10  Sauropsida    Squamata  Colubridae     Natrix        natrix
# 11  Sauropsida    Squamata  Colubridae     Natrix        natrix
# 12  Sauropsida    Squamata  Colubridae     Natrix         maura
# 13  Sauropsida    Squamata  Colubridae     Natrix    tessellata
# 14  Sauropsida    Squamata   Viperidae     Vipera         aspis
# 15  Sauropsida    Squamata   Viperidae     Vipera         aspis
# 16  Sauropsida    Squamata   Viperidae     Vipera         aspis
# 17  Sauropsida    Squamata   Viperidae     Vipera         berus
# 18  Sauropsida    Squamata   Viperidae     Vipera         berus
#
#       sous-espèce                                       dt name cat  \
# 0     orbicularis                              Sumpfschildkröte  CR
# 1          agilis                                  Zauneidechse  VU
# 2       bilineata                               Smaragdeidechse  VU
# 3         muralis                       Mauereidechse (muralis)  LC
# 4   maculiventris               Mauereidechse\n (maculiventris)  LC
# 5        vivipara                                  Waldeidechse  LC
# 6        fragilis                                Blindschleiche  LC
# 7    viridiflavus                                    Zornnatter  EN
# 8             NaN                                 Äskulapnatter  EN
# 9       austriaca                                 Schlingnatter  VU
# 10         natrix                         Ringelnatter (natrix)  EN
# 11      helvetica  Ringelnatter (helvetica), Barrenringelnatter  VU
# 12            NaN                                   Vipernatter  CR
# 13            NaN                                  Würfelnatter  EN
# 14          aspis                                     Juraviper  CR
# 15           atra                                    Alpenviper  VU
# 16  francisciredi                                     Rediviper  EN
# 17          berus                  Kreuzotter (nördliche Klade)  EN
# 18          berus             Kreuzotter\n (italienische Klade)  EN
#
#                   criteria                                        bemerkungen
# 0            B2a, B2b(iii)                                                NaN
# 1         B2a, B2b(ii,iii)                                Genereller Rückgang
# 2        B2a, B2b(iii, iv)         Starker Rückgang in den Kantonen VD und GE
# 3                      NaN               Gefährdet in den Kantonen AG, SH, ZH
# 4                      NaN                                                NaN
# 5                      NaN                                                NaN
# 6                      NaN                               Rückgang im Tiefland
# 7        B2a, B2b(iii, iv)          Kleines Verbreitungsgebiet in der Schweiz
# 8        B2a, B2b(iii, iv)          Kleines Verbreitungsgebiet in der Schweiz
# 9        B2a, B2b(iii, iv)               Im Mittelland vom Aussterben bedroht
# 10  A2c, B2a, B2b(iii, iv)                                     Nordostschweiz
# 11  A2c, B2a, B2b(iii, iv)                    Genereller Rückgang im Tiefland
# 12       B2a, B2b(iii,iv)􀃃                                         GE, VD, VS
# 13        B2a, B2b(iii,iv)                                     Alpensüdflanke
# 14            B2a, B2b(iv)         Genereller Rückgang, regional ausgestorben
# 15   A2c, B2a, B2b(iii,iv)                          Rückgang in den Tieflagen
# 16         B2a, B2(iii,iv)                                     Alpensüdflanke
# 17       A2c, B2a, B2b(iv)  Regional ausgestorben, lokal kritische Populat...
# 18   A2c, B2a, B2b(iii,iv)          Kleines Verbreitungsgebiet in der Schweiz

# %%
df.pop("criteria")
# Out:
# 0              B2a, B2b(iii)
# 1           B2a, B2b(ii,iii)
# 2          B2a, B2b(iii, iv)
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7          B2a, B2b(iii, iv)
# 8          B2a, B2b(iii, iv)
# 9          B2a, B2b(iii, iv)
# 10    A2c, B2a, B2b(iii, iv)
# 11    A2c, B2a, B2b(iii, iv)
# 12         B2a, B2b(iii,iv)􀃃
# 13          B2a, B2b(iii,iv)
# 14              B2a, B2b(iv)
# 15     A2c, B2a, B2b(iii,iv)
# 16           B2a, B2(iii,iv)
# 17         A2c, B2a, B2b(iv)
# 18     A2c, B2a, B2b(iii,iv)
# Name: criteria, dtype: object

# %%
df.pop("sous-espèce")
# Out:
# 0       orbicularis
# 1            agilis
# 2         bilineata
# 3           muralis
# 4     maculiventris
# 5          vivipara
# 6          fragilis
# 7      viridiflavus
# 8               NaN
# 9         austriaca
# 10           natrix
# 11        helvetica
# 12              NaN
# 13              NaN
# 14            aspis
# 15             atra
# 16    francisciredi
# 17            berus
# 18            berus
# Name: sous-espèce, dtype: object

# %%
df.head()
# Out:
#         group       order      family     genus      species  \
# 0  Sauropsida  Cheloniens    Emydidae      Emys  orbicularis
# 1  Sauropsida    Squamata  Lacertidae   Lacerta       agilis
# 2  Sauropsida    Squamata  Lacertidae   Lacerta    bilineata
# 3  Sauropsida    Squamata  Lacertidae  Podarcis      muralis
# 4  Sauropsida    Squamata  Lacertidae  Podarcis      muralis
#
#                            dt name cat  \
# 0                 Sumpfschildkröte  CR
# 1                     Zauneidechse  VU
# 2                  Smaragdeidechse  VU
# 3          Mauereidechse (muralis)  LC
# 4  Mauereidechse\n (maculiventris)  LC
#
#                                   bemerkungen
# 0                                         NaN
# 1                         Genereller Rückgang
# 2  Starker Rückgang in den Kantonen VD und GE
# 3        Gefährdet in den Kantonen AG, SH, ZH
# 4                                         NaN

# %%
df['einteilung'] = 'Reptilien'

# %%
df.head()
# Out:
#         group       order      family     genus      species  \
# 0  Sauropsida  Cheloniens    Emydidae      Emys  orbicularis
# 1  Sauropsida    Squamata  Lacertidae   Lacerta       agilis
# 2  Sauropsida    Squamata  Lacertidae   Lacerta    bilineata
# 3  Sauropsida    Squamata  Lacertidae  Podarcis      muralis
# 4  Sauropsida    Squamata  Lacertidae  Podarcis      muralis
#
#                            dt name cat  \
# 0                 Sumpfschildkröte  CR
# 1                     Zauneidechse  VU
# 2                  Smaragdeidechse  VU
# 3          Mauereidechse (muralis)  LC
# 4  Mauereidechse\n (maculiventris)  LC
#
#                                   bemerkungen einteilung
# 0                                         NaN  Reptilien
# 1                         Genereller Rückgang  Reptilien
# 2  Starker Rückgang in den Kantonen VD und GE  Reptilien
# 3        Gefährdet in den Kantonen AG, SH, ZH  Reptilien
# 4                                         NaN  Reptilien

# %%
df["cat"].value_counts()
# Out:
# EN    7
# VU    5
# LC    4
# CR    3
# Name: cat, dtype: int64

# %%
values = [0, 0, 3, 7, 5, 0, 4, 0, 0]
colors = ['r', 'r', 'r', 'r', 'r', 'g', "g", "grey", "grey"]
labels = [
    'EX: ausgestorben', 'RE: CH ausgestorben',
    'CR: v. aussterben bedroht', 'EN: stark gefährdet', 
    'VU: verletzlich',"NT: potenziell gef.",
    "LC: nicht gef.","DD: ungen. Daten","NE: nicht beurteilt"]


fig1, ax1 = plt.subplots(figsize=(7, 6))
fig1.subplots_adjust(0.3,0,1,1)
plt.pie(values, colors=colors, labels= values, counterclock=False,startangle=90)
plt.title('Gefährdung Reptilien, 19 Arten')

total = sum(values)
plt.legend(
    loc='upper left',
    labels=['%s, %1.1f%%' % (
        l, (float(s) / total) * 100) for l, s in zip(labels, values)],
    
    bbox_to_anchor=(1.0, 0.5),
    bbox_transform=fig1.transFigure
)
plt.show()
