# %% [markdown]
# # MAZ Diplomarbeit - Biodiversität in der Schweiz#

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("01_source/xls_ch/heuschrecken_ch.csv")

# %%
df.head()
# Out:
#     classe       ordre       famille        genre  \
# 0  Insecta  orthoptera  Tettigonidae  Anonconotus
# 1  Insecta  orthoptera  Tettigonidae     Antaxius
# 2  Insecta  orthoptera  Tettigonidae     Antaxius
# 3  Insecta  orthoptera  Tettigonidae  Barbitistes
# 4  Insecta  orthoptera  Tettigonidae  Barbitistes
#
#                                     espèce  \
# 0                   alpinus (Yersin, 1858)
# 1  difformis (Brunner von Wattenwyl, 1861)
# 2              pedestris (Fabricius, 1787)
# 3          obtusus Targioni-Tozzetti, 1881
# 4             serricauda (Fabricius, 1794)
#
#                                    nom scientifique                         D  \
# 0                Anonconotus alpinus (Yersin, 1858)             Alpenschrecke
# 1  Antaxius difformis (Brunner von Wattenwyl, 1861)       Alpine Bergschrecke
# 2              Antaxius pedestris (Fabricius, 1787)  Atlantische Bergschrecke
# 3       Barbitistes obtusus Targioni-Tozzetti, 1881    Südalpen-Säbelschrecke
# ...

# %%
len (df)
# Out:
# 112

# %%
df.shape
# Out:
# (112, 11)

# %%
df["Cat."].value_counts()
# Out:
# LC    43
# VU    19
# NT    19
# CR    10
# EN     8
# NE     7
# DD     3
# RE     3
# Name: Cat., dtype: int64

# %%
df.rename(columns={"classe":"group", "ordre": "order","famille":"family","genre":"genus","espèce":"species","nom scientifique": "sc name", "D":"dt name", "Cat.":"cat","Criteria UICN":"criteria", "Bemerkungen":"bemerkungen"},inplace=True)

# %%
df
# Out:
#        group       order        family           genus  \
# 0    Insecta  orthoptera  Tettigonidae     Anonconotus
# 1    Insecta  orthoptera  Tettigonidae        Antaxius
# 2    Insecta  orthoptera  Tettigonidae        Antaxius
# 3    Insecta  orthoptera  Tettigonidae     Barbitistes
# 4    Insecta  orthoptera  Tettigonidae     Barbitistes
# 5    Insecta  orthoptera  Tettigonidae    Conocephalus
# 6    Insecta  orthoptera  Tettigonidae    Conocephalus
# 7    Insecta  orthoptera  Tettigonidae        Decticus
# 8    Insecta  orthoptera  Tettigonidae      Ephippiger
# 9    Insecta  orthoptera  Tettigonidae      Ephippiger
# 10   Insecta  orthoptera  Tettigonidae      Ephippiger
# 11   Insecta  orthoptera  Tettigonidae  Eupholidoptera
# 12   Insecta  orthoptera  Tettigonidae      Leptophyes
# 13   Insecta  orthoptera  Tettigonidae      Leptophyes
# 14   Insecta  orthoptera  Tettigonidae      Leptophyes
# 15   Insecta  orthoptera  Tettigonidae        Meconema
# ...

# %%
df.pop('criteria')
# Out:
# 0                B2a, B2b(iii,iv)
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                B2a, B2b(iii,iv)
# 6                     B2b(iii,iv)
# 7                             NaN
# 8                B2a, B2b(iii,iv)
# 9                     B2b(iii,iv)
# 10                    B2b(iii,iv)
# 11                            NaN
# 12                            NaN
# 13                            NaN
# 14                            NaN
# 15                            NaN
# 16                            NaN
# 17                    B2b(iii,iv)
# 18                            NaN
# 19                            NaN
# 20                            NaN
# 21                            NaN
# 22          B2a, B2b(i,ii,iii,iv)
# 23                    B2b(iii,iv)
# 24                            NaN
# 25                            NaN
# 26                            NaN
# ...

# %%
df.pop("Prot.")
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      §CH
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# 20     NaN
# 21     NaN
# 22     §CH
# 23     NaN
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28     §CH
# 29     NaN
#       ...
# 82     NaN
# 83     NaN
# 84     NaN
# 85     NaN
# 86     NaN
# 87     NaN
# 88     §CH
# 89     NaN
# 90     NaN
# 91     NaN
# 92     NaN
# 93     §CH
# 94     NaN
# 95     NaN
# 96     §CH
# 97     §CH
# 98     §CH
# 99     NaN
# 100    NaN
# 101    NaN
# 102    NaN
# 103    §CH
# 104    §CH
# 105    §CH
# 106    NaN
# 107    NaN
# 108    NaN
# 109    NaN
# 110    NaN
# 111    §CH
# Name: Prot., Length: 112, dtype: object

# %%
df.pop("species")
# Out:
# 0                        alpinus (Yersin, 1858)
# 1       difformis (Brunner von Wattenwyl, 1861)
# 2                   pedestris (Fabricius, 1787)
# 3               obtusus Targioni-Tozzetti, 1881
# 4                  serricauda (Fabricius, 1794)
# 5                    dorsalis (Latreille, 1804)
# 6                      fuscus (Fabricius, 1793)
# 7                 verrucivorus (Linnaeus, 1758)
# 8               ephippiger diurnus Dufour, 1841
# 9       terrestris bormansi von Wattenwyl, 1882
# 10                           vicheti Harz, 1966
# 11                chabrieri (Charpentier, 1825)
# 12                   albovittata (Kollar, 1833)
# 13                 laticauda (Frivaldsky, 1867)
# 14                   punctatissima (Bosc, 1792)
# 15                      meridionale Costa, 1860
# 16                  thalassinum (De Geer, 1773)
# 17                     bicolor (Philippi, 1830)
# 18                 brachyptera (Linnaeus, 1761)
# 19             fedtschenkoi minor (Nadig, 1961)
# ...

# %%
df.pop("genus")
# Out:
# 0         Anonconotus
# 1            Antaxius
# 2            Antaxius
# 3         Barbitistes
# 4         Barbitistes
# 5        Conocephalus
# 6        Conocephalus
# 7            Decticus
# 8          Ephippiger
# 9          Ephippiger
# 10         Ephippiger
# 11     Eupholidoptera
# 12         Leptophyes
# 13         Leptophyes
# 14         Leptophyes
# 15           Meconema
# 16           Meconema
# 17        Metrioptera
# 18        Metrioptera
# 19        Metrioptera
# 20        Metrioptera
# 21        Metrioptera
# 22       Pachytrachis
# 23       Phaneroptera
# 24       Phaneroptera
# 25       Pholidoptera
# 26       Pholidoptera
# 27       Pholidoptera
# 28       Pholidoptera
# 29         Platycleis
#             ...
# 82        Chorthippus
# 83        Chorthippus
# 84        Chorthippus
# 85        Chorthippus
# 86        Chorthippus
# 87       Chrysochraon
# 88         Epacromius
# 89      Euchorthippus
# 90         Euthystira
# 91     Gomphocerippus
# ...

# %%
df
# Out:
#        group       order        family  \
# 0    Insecta  orthoptera  Tettigonidae
# 1    Insecta  orthoptera  Tettigonidae
# 2    Insecta  orthoptera  Tettigonidae
# 3    Insecta  orthoptera  Tettigonidae
# 4    Insecta  orthoptera  Tettigonidae
# 5    Insecta  orthoptera  Tettigonidae
# 6    Insecta  orthoptera  Tettigonidae
# 7    Insecta  orthoptera  Tettigonidae
# 8    Insecta  orthoptera  Tettigonidae
# 9    Insecta  orthoptera  Tettigonidae
# 10   Insecta  orthoptera  Tettigonidae
# 11   Insecta  orthoptera  Tettigonidae
# 12   Insecta  orthoptera  Tettigonidae
# 13   Insecta  orthoptera  Tettigonidae
# 14   Insecta  orthoptera  Tettigonidae
# 15   Insecta  orthoptera  Tettigonidae
# 16   Insecta  orthoptera  Tettigonidae
# 17   Insecta  orthoptera  Tettigonidae
# 18   Insecta  orthoptera  Tettigonidae
# 19   Insecta  orthoptera  Tettigonidae
# 20   Insecta  orthoptera  Tettigonidae
# 21   Insecta  orthoptera  Tettigonidae
# 22   Insecta  orthoptera  Tettigonidae
# ...

# %%
df['einteilung'] = 'Insekten'

# %%
df.head(2)
# Out:
#      group       order        family  \
# 0  Insecta  orthoptera  Tettigonidae
# 1  Insecta  orthoptera  Tettigonidae
#
#                                             sc name              dt name cat  \
# 0                Anonconotus alpinus (Yersin, 1858)        Alpenschrecke  VU
# 1  Antaxius difformis (Brunner von Wattenwyl, 1861)  Alpine Bergschrecke  NT
#
#    bemerkungen einteilung
# 0  Grünlandart   Insekten
# 1          NaN   Insekten

# %%
df["cat"].value_counts()
# Out:
# LC    43
# VU    19
# NT    19
# CR    10
# EN     8
# NE     7
# DD     3
# RE     3
# Name: cat, dtype: int64

# %%
values = [0, 3, 10, 8, 19, 19, 43, 3, 7]
colors = ['r', 'r', 'r', 'r', 'r', 'g', "g", "grey", "grey"]
labels = [
    'EX: ausgestorben', 'RE: CH ausgestorben',
    'CR: v. aussterben bedroht', 'EN: stark gefährdet', 
    'VU: verletzlich',"NT: potenziell gef.",
    "LC: nicht gef.","DD: ungen. Daten","NE: nicht beurteilt"]


fig1, ax1 = plt.subplots(figsize=(7, 6))
fig1.subplots_adjust(0.3,0,1,1)
plt.pie(values, colors=colors, labels= values, counterclock=False,startangle=90)
plt.title('Gefährdung Heuschrecken, 112 Arten')

total = sum(values)
plt.legend(
    loc='upper left',
    labels=['%s, %1.1f%%' % (
        l, (float(s) / total) * 100) for l, s in zip(labels, values)],
    
    bbox_to_anchor=(1.0, 0.5),
    bbox_transform=fig1.transFigure
)
plt.show()

# %%
values = [0, 3, 10, 8, 19, 19, 43, 0, 0]
colors = ['r', 'r', 'r', 'r', 'r', 'g', "g", "grey", "grey"]
labels = [
    'EX: ausgestorben', 'RE: CH ausgestorben',
    'CR: v. aussterben bedroht', 'EN: stark gefährdet', 
    'VU: verletzlich',"NT: potenziell gef.",
    "LC: nicht gef.","DD: ungen. Daten","NE: nicht beurteilt"]


fig1, ax1 = plt.subplots(figsize=(7, 6))
fig1.subplots_adjust(0.3,0,1,1)
plt.pie(values, colors=colors, labels= values, counterclock=False,startangle=90)
plt.title('Gefährdung Heuschrecken, 102 dokumentierte Arten')

total = sum(values)
plt.legend(
    loc='upper left',
    labels=['%s, %1.1f%%' % (
        l, (float(s) / total) * 100) for l, s in zip(labels, values)],
    
    bbox_to_anchor=(1.0, 0.5),
    bbox_transform=fig1.transFigure
)
plt.show()
