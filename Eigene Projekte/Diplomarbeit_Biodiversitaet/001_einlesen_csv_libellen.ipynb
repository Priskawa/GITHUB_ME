# %% [markdown]
# # MAZ Diplomarbeit - Biodiversität in der Schweiz#

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("01_source/xls_ch/libellen_ch.csv")

# %%
df.head()
# Out:
#     classe    ordre         famille       genre     espèce   sous-espèce  \
# 0  Insecta  Odonata  Calopterygidae  Calopteryx  splendens     splendens
# 1  Insecta  Odonata  Calopterygidae  Calopteryx  splendens        caprai
# 2  Insecta  Odonata  Calopterygidae  Calopteryx  splendens   xanthostoma
# 3  Insecta  Odonata  Calopterygidae  Calopteryx      virgo         virgo
# 4  Insecta  Odonata  Calopterygidae  Calopteryx      virgo  meridionalis
#
#                           D statut CH critères  \
# 0  Gebänderte Prachtlibelle        LC      NaN
# 1                       NaN        NT    B1,B2
# 2                       NaN        DD      NaN
# 3  Blauflügel-Prachtlibelle        LC      NaN
# 4    Südliche Prachtlibelle        VU     B2 b
#
#                                          Bemerkungen
# 0                                                NaN
# 1                            Zunahme in den Südalpen
# 2                                                NaN
# 3                                                NaN
# 4  ihre seltenen Populationen sind stabil, aber i...

# %%
len (df)
# Out:
# 82

# %%
df.shape
# Out:
# (82, 10)

# %%
df["statut CH"].value_counts()
# Out:
# LC    34
# NT    12
# CR    12
# EN     7
# NE     6
# VU     5
# DD     4
# RE     2
# Name: statut CH, dtype: int64

# %%
df.rename(columns={"classe":"group","ordre":"order","famille":"family","genre":"genus","espèce":"species","D":"dt name","statut CH":"cat","critères":"criteria", "Bemerkungen": "bemerkungen"},inplace=True)

# %%
df
# Out:
#       group    order            family          genus          species  \
# 0   Insecta  Odonata    Calopterygidae     Calopteryx        splendens
# 1   Insecta  Odonata    Calopterygidae     Calopteryx        splendens
# 2   Insecta  Odonata    Calopterygidae     Calopteryx        splendens
# 3   Insecta  Odonata    Calopterygidae     Calopteryx            virgo
# 4   Insecta  Odonata    Calopterygidae     Calopteryx            virgo
# 5   Insecta  Odonata          Lestidae   Chalcolestes          viridis
# 6   Insecta  Odonata          Lestidae         Lestes         barbarus
# 7   Insecta  Odonata          Lestidae         Lestes            dryas
# 8   Insecta  Odonata          Lestidae         Lestes      macrostigma
# 9   Insecta  Odonata          Lestidae         Lestes           sponsa
# 10  Insecta  Odonata          Lestidae         Lestes           virens
# 11  Insecta  Odonata          Lestidae       Sympecma            fusca
# 12  Insecta  Odonata          Lestidae       Sympecma         paedisca
# 13  Insecta  Odonata   Platycnemididae    Platycnemis         pennipes
# 14  Insecta  Odonata    Coenagrionidae        Cercion         lindenii
# 15  Insecta  Odonata    Coenagrionidae     Ceriagrion         tenellum
# 16  Insecta  Odonata    Coenagrionidae     Coenagrion       hastulatum
# 17  Insecta  Odonata    Coenagrionidae     Coenagrion        lunulatum
# 18  Insecta  Odonata    Coenagrionidae     Coenagrion       mercuriale
# 19  Insecta  Odonata    Coenagrionidae     Coenagrion          ornatum
# 20  Insecta  Odonata    Coenagrionidae     Coenagrion           puella
# 21  Insecta  Odonata    Coenagrionidae     Coenagrion       pulchellum
# 22  Insecta  Odonata    Coenagrionidae     Coenagrion         scitulum
# 23  Insecta  Odonata    Coenagrionidae      Enallagma      cyathigerum
# 24  Insecta  Odonata    Coenagrionidae     Erythromma            najas
# 25  Insecta  Odonata    Coenagrionidae     Erythromma        viridulum
# 26  Insecta  Odonata    Coenagrionidae       Ischnura          elegans
# 27  Insecta  Odonata    Coenagrionidae       Ischnura          pumilio
# 28  Insecta  Odonata    Coenagrionidae     Nehalennia         speciosa
# 29  Insecta  Odonata    Coenagrionidae     Pyrrhosoma         nymphula
# ..      ...      ...               ...            ...              ...
# 52  Insecta  Odonata  Cordulegastridae  Cordulegaster         boltonii
# 53  Insecta  Odonata       Corduliidae       Cordulia            aenea
# 54  Insecta  Odonata       Corduliidae       Epitheca       bimaculata
# 55  Insecta  Odonata       Corduliidae      Oxygastra         curtisii
# 56  Insecta  Odonata       Corduliidae   Somatochlora        alpestris
# 57  Insecta  Odonata       Corduliidae   Somatochlora          arctica
# 58  Insecta  Odonata       Corduliidae   Somatochlora    flavomaculata
# 59  Insecta  Odonata       Corduliidae   Somatochlora        metallica
# 60  Insecta  Odonata      Libellulidae    Crocothemis        erythraea
# 61  Insecta  Odonata      Libellulidae   Leucorrhinia        albifrons
# 62  Insecta  Odonata      Libellulidae   Leucorrhinia         caudalis
# 63  Insecta  Odonata      Libellulidae   Leucorrhinia            dubia
# 64  Insecta  Odonata      Libellulidae   Leucorrhinia       pectoralis
# 65  Insecta  Odonata      Libellulidae   Leucorrhinia        rubicunda
# 66  Insecta  Odonata      Libellulidae      Libellula         depressa
# 67  Insecta  Odonata      Libellulidae      Libellula            fulva
# 68  Insecta  Odonata      Libellulidae      Libellula   quadrimaculata
# 69  Insecta  Odonata      Libellulidae      Orthetrum       albistylum
# 70  Insecta  Odonata      Libellulidae      Orthetrum         brunneum
# 71  Insecta  Odonata      Libellulidae      Orthetrum      cancellatum
# 72  Insecta  Odonata      Libellulidae      Orthetrum     coerulescens
# 73  Insecta  Odonata      Libellulidae      Sympetrum            danae
# 74  Insecta  Odonata      Libellulidae      Sympetrum  depressiusculum
# 75  Insecta  Odonata      Libellulidae      Sympetrum        flaveolum
# 76  Insecta  Odonata      Libellulidae      Sympetrum     fonscolombii
# 77  Insecta  Odonata      Libellulidae      Sympetrum      meridionale
# 78  Insecta  Odonata      Libellulidae      Sympetrum     pedemontanum
# 79  Insecta  Odonata      Libellulidae      Sympetrum       sanguineum
# 80  Insecta  Odonata      Libellulidae      Sympetrum       striolatum
# 81  Insecta  Odonata      Libellulidae      Sympetrum         vulgatum
#
#      sous-espèce                      dt name cat  criteria  \
# 0      splendens     Gebänderte Prachtlibelle  LC       NaN
# 1         caprai                          NaN  NT     B1,B2
# 2    xanthostoma                          NaN  DD       NaN
# 3          virgo     Blauflügel-Prachtlibelle  LC       NaN
# 4   meridionalis       Südliche Prachtlibelle  VU      B2 b
# 5            NaN                Weidenjungfer  LC       NaN
# 6            NaN       Südliche Binsenjungfer  NE       NaN
# 7            NaN      Glänzende Binsenjungfer  CR   B2 a, b
# 8            NaN         Dunkle Binsenjungfer  DD       NaN
# 9            NaN        Gemeine Binsenjungfer  NT       A2c
# 10      vestalis         Kleine Binsenjungfer  CR   B2 a, b
# 11           NaN        Gemeine Winterlibelle  LC       NaN
# 12           NaN     Sibirische Winterlibelle  CR   B2a, 2b
# 13           NaN                 Federlibelle  LC       NaN
# 14           NaN            Pokal-Azurjungfer  NT       NaN
# 15           NaN          Späte Adonislibelle  EN   B2a, 2b
# 16           NaN            Speer-Azurjungfer  NT   B2a, 2b
# 17           NaN            Mond- Azurjungfer  CR   B2a, 2b
# 18           NaN             Helm-Azurjungfer  CR   B2a, 2b
# 19           NaN            Vogel-Azurjungfer  RE       NaN
# 20           NaN         Hufeisen-Azurjungfer  LC       NaN
# 21           NaN       Fledermaus-Azurjungfer  NT        A2
# 22           NaN            Gabel-Azurjungfer  DD       NaN
# 23           NaN           Becher-Azurjungfer  LC       NaN
# 24           NaN           Grosses Granatauge  LC       NaN
# 25           NaN           Kleines Granatauge  LC       NaN
# 26           NaN           Grosse Pechlibelle  LC       NaN
# 27           NaN           Kleine Pechlibelle  LC       NaN
# 28           NaN                 Zwerglibelle  CR   B2a, 2b
# 29           NaN          Frühe Adonislibelle  LC       NaN
# ..           ...                          ...  ..       ...
# 52           NaN  Zweigestreifte Quelljungfer  LC       NaN
# 53           NaN       Gemeine Smaragdlibelle  LC       NaN
# 54           NaN     Zweifleck-Smaragdlibelle  CR   B2a, 2b
# 55           NaN      Gekielte Smaragdlibelle  EN  B1a, B2a
# 56           NaN         Alpen-Smaragdlibelle  LC       NaN
# 57           NaN     Artkische Smaragdlibelle  NT   B2a, 2b
# 58           NaN     Gefleckte Smaragdlibelle  LC       NaN
# 59           NaN     Glänzende Smaragdlibelle  LC       NaN
# 60           NaN                 Feuerlibelle  LC       NaN
# 61           NaN         Östliche Moosjungfer  CR   B2a, 2b
# 62           NaN        Zierliche Moosjungfer  CR   B2a, 2b
# 63           NaN           Kleine Moosjungfer  NT   B2a, 2b
# 64           NaN           Grosse Moosjungfer  CR   B2a, 2b
# 65           NaN        Nordische Moosjungfer  NE       NaN
# 66           NaN                   Plattbauch  LC       NaN
# 67           NaN                 Spitzenfleck  LC       NaN
# 68           NaN                    Vierfleck  LC       NaN
# 69           NaN          Östlicher Blaupfeil  EN   A2, B2b
# 70           NaN          Südlicher Blaupfeil  LC       NaN
# 71           NaN            Grosser Blaupfeil  LC       NaN
# 72           NaN            Kleiner Blaupfeil  NT       B2b
# 73           NaN        Schwarze Heidelibelle  NT       B2b
# 74           NaN           Sumpf-Heidelibelle  VU   B2a, 2b
# 75           NaN       Gefleckte Heidelibelle  EN   A2, B2b
# 76           NaN           Frühe Heidelibelle  NE       NaN
# 77           NaN        Südliche Heidelibelle  NE       NaN
# 78           NaN      Gebänderte Heidelibelle  CR   B2a, 2b
# 79           NaN        Blutrote Heidelibelle  LC       NaN
# 80           NaN          Grosse Heidelibelle  LC       NaN
# 81           NaN         Gemeine Heidelibelle  LC       NaN
#
#                                           bemerkungen
# 0                                                 NaN
# 1                             Zunahme in den Südalpen
# 2                                                 NaN
# 3                                                 NaN
# 4   ihre seltenen Populationen sind stabil, aber i...
# 5                                                 NaN
# 6                                                 NaN
# 7                                    starker Rückgang
# 8                                                 NaN
# 9   starker Rückgang, aber noch häufige Population...
# 10                                   starker Rückgang
# 11                                                NaN
# 12                                           Rückgang
# 13                                                NaN
# 14  besiedelt künstliche Lebensräume und erhält si...
# 15  stabilisierte, aber meistens isolierte Populat...
# 16  stabilisierte Populationen, aber empfindliche ...
# 17                            letzte Beobachtung 1989
# 18  stabilisierte Populationen, aber grosse Zerstü...
# 19                            letzte Beobachtung 1957
# 20                                                NaN
# 21                                   starker Rückgang
# 22                           1 Standort 2001 entdeckt
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                            letzte Beobachtung 1990
# 29                                                NaN
# ..                                                ...
# 52                                                NaN
# 53                                                NaN
# 54     stark isolierte Populationen, starker Rückgang
# 55                           sehr lokale Populationen
# 56                                                NaN
# 57                           empfindlicher Lebensraum
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
# 61                       extreme Isolierung, Rückgang
# 62                       extreme Isolierung, Rückgang
# 63                           empfindlicher Lebensraum
# 64                                   starker Rückgang
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
# 68                                                NaN
# 69                                   starker Rückgang
# 70                                                NaN
# 71                                                NaN
# 72                           empfindlicher Lebensraum
# 73                                           Rückgang
# 74                           empfindlicher Lebensraum
# 75                                   starker Rückgang
# 76                                                NaN
# 77                                                NaN
# 78                                   starker Rückgang
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
#
# [82 rows x 10 columns]

# %%
df.pop("criteria")
df.pop("sous-espèce")
df.pop("genus")
df.pop("species")
# Out:
# 0           splendens
# 1           splendens
# 2           splendens
# 3               virgo
# 4               virgo
# 5             viridis
# 6            barbarus
# 7               dryas
# 8         macrostigma
# 9              sponsa
# 10             virens
# 11              fusca
# 12           paedisca
# 13           pennipes
# 14           lindenii
# 15           tenellum
# 16         hastulatum
# 17          lunulatum
# 18         mercuriale
# 19            ornatum
# 20             puella
# 21         pulchellum
# 22           scitulum
# 23        cyathigerum
# 24              najas
# 25          viridulum
# 26            elegans
# 27            pumilio
# 28           speciosa
# 29           nymphula
#            ...
# 52           boltonii
# 53              aenea
# 54         bimaculata
# 55           curtisii
# 56          alpestris
# 57            arctica
# 58      flavomaculata
# 59          metallica
# 60          erythraea
# 61          albifrons
# 62           caudalis
# 63              dubia
# 64         pectoralis
# 65          rubicunda
# 66           depressa
# 67              fulva
# 68     quadrimaculata
# 69         albistylum
# 70           brunneum
# 71        cancellatum
# 72       coerulescens
# 73              danae
# 74    depressiusculum
# 75          flaveolum
# 76       fonscolombii
# 77        meridionale
# 78       pedemontanum
# 79         sanguineum
# 80         striolatum
# 81           vulgatum
# Name: species, Length: 82, dtype: object

# %%
df['einteilung'] = 'Insekten'

# %%
df.head(2)
# Out:
#      group    order          family                   dt name cat  \
# 0  Insecta  Odonata  Calopterygidae  Gebänderte Prachtlibelle  LC
# 1  Insecta  Odonata  Calopterygidae                       NaN  NT
#
#                bemerkungen einteilung
# 0                      NaN   Insekten
# 1  Zunahme in den Südalpen   Insekten

# %%
df["cat"].value_counts()
# Out:
# LC    34
# NT    12
# CR    12
# EN     7
# NE     6
# VU     5
# DD     4
# RE     2
# Name: cat, dtype: int64

# %%
values = [0, 2, 12, 7, 5, 12, 34, 4, 6]
colors = ['r', 'r', 'r', 'r', 'r', 'g', "g", "grey", "grey"]
labels = [
    'EX: ausgestorben', 'RE: CH ausgestorben',
    'CR: v. aussterben bedroht', 'EN: stark gefährdet', 
    'VU: verletzlich',"NT: potenziell gef.",
    "LC: nicht gef.","DD: ungen. Daten","NE: nicht beurteilt"]


fig1, ax1 = plt.subplots(figsize=(7, 6))
fig1.subplots_adjust(0.3,0,1,1)
plt.pie(values, colors=colors, labels= values, counterclock=False,startangle=90)
plt.title('Gefährdung Libellen, 82 Arten')

total = sum(values)
plt.legend(
    loc='upper left',
    labels=['%s, %1.1f%%' % (
        l, (float(s) / total) * 100) for l, s in zip(labels, values)],
    
    bbox_to_anchor=(1.0, 0.5),
    bbox_transform=fig1.transFigure
)
plt.show()

# %%
values = [0, 2, 12, 7, 5, 12, 34, 0, 0]
colors = ['r', 'r', 'r', 'r', 'r', 'g', "g", "grey", "grey"]
labels = [
    'EX: ausgestorben', 'RE: CH ausgestorben',
    'CR: v. aussterben bedroht', 'EN: stark gefährdet', 
    'VU: verletzlich',"NT: potenziell gef.",
    "LC: nicht gef.","DD: ungen. Daten","NE: nicht beurteilt"]


fig1, ax1 = plt.subplots(figsize=(7, 6))
fig1.subplots_adjust(0.3,0,1,1)
plt.pie(values, colors=colors, labels= values, counterclock=False,startangle=90)
plt.title('Gefährdung Libellen, 72 dokumentierte Arten')

total = sum(values)
plt.legend(
    loc='upper left',
    labels=['%s, %1.1f%%' % (
        l, (float(s) / total) * 100) for l, s in zip(labels, values)],
    
    bbox_to_anchor=(1.0, 0.5),
    bbox_transform=fig1.transFigure
)
plt.show()
