# %% [markdown]
# # MAZ Diplomarbeit - Biodiversität in der Schweiz#

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("01_source/xls_ch/gefaesspflanzen_ch.csv")

# %%
df.head()
# Out:
#    ID_ISFS          GROUP       FAMILY  GENUS     SPECIES SSP  \
# 0      100    Gymnosperma     Pinaceae  Abies            alba
# 1      300  Dicotyledones  Sapindaceae   Acer       campestre
# 2      600  Dicotyledones  Sapindaceae   Acer          opalus
# 3      700  Dicotyledones  Sapindaceae   Acer     platanoides
# 4      800  Dicotyledones  Sapindaceae   Acer  pseudoplatanus
#
#        Scientific name              Deutscher Name CAT Criteria Bemerkungen
# 0           Abies alba                       Tanne  LC      NaN         NaN
# 1       Acer campestre                  Feld-Ahorn  LC      NaN         NaN
# 2          Acer opalus  Schneeballblättriger Ahorn  LC      NaN         NaN
# 3     Acer platanoides                 Spitz-Ahorn  LC      NaN         NaN
# 4  Acer pseudoplatanus                  Berg-Ahorn  LC      NaN         NaN

# %%
len (df)
# Out:
# 2915

# %%
df.shape
# Out:
# (2915, 10)

# %%
df["CAT"].value_counts()
# Out:
# LC        1643
# NT         437
# VU         368
# EN         200
# CR         113
# DD          99
# RE          35
# CR(PE)      19
# EX           1
# Name: CAT, dtype: int64

# %%
df.groupby("GROUP")["CAT"].value_counts()
# Out:
# GROUP            CAT
# Dicotyledones    LC        1262
#                  NT         331
#                  VU         256
#                  EN         141
#                  CR          75
#                  DD          73
#                  RE          27
#                  CR(PE)      12
#                  EX           1
# Gymnosperma      LC          13
#                  VU           1
# Monocotyledones  LC         319
#                  NT         102
#                  VU          97
#                  EN          53
#                  CR          29
#                  DD          21
#                  CR(PE)       7
#                  RE           7
# Pteridophyta     LC          49
#                  VU          14
#                  CR           9
#                  EN           6
#                  DD           5
#                  NT           4
#                  RE           1
# Name: CAT, dtype: int64

# %%
df.pop('ID_ISFS')
# Out:
# 0          100
# 1          300
# 2          600
# 3          700
# 4          800
# 5          900
# 6         1000
# 7         1100
# 8         1200
# 9         1500
# 10        1600
# 11        1700
# 12        1705
# 13        1900
# 14        2000
# 15        2150
# 16        2200
# 17        2300
# 18        2400
# 19        2500
# 20        2600
# 21        2700
# 22        2800
# 23        2900
# 24        3100
# 25        3510
# 26        3520
# 27        3530
# 28        3540
# 29        3560
#          ...
# 2885    451000
# 2886    451100
# 2887    451200
# 2888    451300
# 2889    451400
# 2890    451500
# 2891    451600
# 2892    451700
# 2893    451800
# 2894    452200
# 2895    452400
# 2896    452501
# 2897    452505
# 2898    452510
# 2899    452600
# 2900    452700
# 2901    452800
# 2902    452900
# 2903    453500
# 2904    453700
# 2905    453800
# 2906    453900
# 2907    454000
# 2908    454200
# 2909    454500
# 2910    454700
# 2911    454800
# ...

# %%
df.head(1)
# Out:
#          GROUP    FAMILY  GENUS SPECIES SSP Scientific name Deutscher Name  \
# 0  Gymnosperma  Pinaceae  Abies        alba      Abies alba          Tanne
#
#   CAT Criteria Bemerkungen
# 0  LC      NaN         NaN

# %%
df.rename(columns={"GROUP":"group","FAMILY":"family","GENUS":"genus","SPECIES SSP":"species","Scientific name":"sc name","Deutscher Name":"dt name","CAT":"cat", "Criteria": "criteria", "Bemerkungen":"bemerkungen"},inplace=True)

# %%
df
# Out:
#                 group            family         genus  \
# 0         Gymnosperma          Pinaceae         Abies
# 1       Dicotyledones       Sapindaceae          Acer
# 2       Dicotyledones       Sapindaceae          Acer
# 3       Dicotyledones       Sapindaceae          Acer
# 4       Dicotyledones       Sapindaceae          Acer
# 5     Monocotyledones       Orchidaceae        Aceras
# 6       Dicotyledones        Asteraceae      Achillea
# 7       Dicotyledones        Asteraceae      Achillea
# 8       Dicotyledones        Asteraceae      Achillea
# 9       Dicotyledones        Asteraceae      Achillea
# 10      Dicotyledones        Asteraceae      Achillea
# 11      Dicotyledones        Asteraceae      Achillea
# 12      Dicotyledones        Asteraceae      Achillea
# 13      Dicotyledones        Asteraceae      Achillea
# 14      Dicotyledones        Asteraceae      Achillea
# 15      Dicotyledones        Asteraceae      Achillea
# ...

# %%
df['einteilung'] = 'Pflanzen'

# %%
df['untergruppe'] = 'Gefässpflanzen'

# %%
df.head()
# Out:
#            group       family  genus         species              sc name  \
# 0    Gymnosperma     Pinaceae  Abies            alba           Abies alba
# 1  Dicotyledones  Sapindaceae   Acer       campestre       Acer campestre
# 2  Dicotyledones  Sapindaceae   Acer          opalus          Acer opalus
# 3  Dicotyledones  Sapindaceae   Acer     platanoides     Acer platanoides
# 4  Dicotyledones  Sapindaceae   Acer  pseudoplatanus  Acer pseudoplatanus
#
#                       dt name cat criteria bemerkungen einteilung  \
# 0                       Tanne  LC      NaN         NaN   Pflanzen
# 1                  Feld-Ahorn  LC      NaN         NaN   Pflanzen
# 2  Schneeballblättriger Ahorn  LC      NaN         NaN   Pflanzen
# 3                 Spitz-Ahorn  LC      NaN         NaN   Pflanzen
# 4                  Berg-Ahorn  LC      NaN         NaN   Pflanzen
#
#       untergruppe
# 0  Gefässpflanzen
# 1  Gefässpflanzen
# 2  Gefässpflanzen
# 3  Gefässpflanzen
# 4  Gefässpflanzen

# %%
df["cat"].value_counts()
# Out:
# LC        1643
# NT         437
# VU         368
# EN         200
# CR         113
# DD          99
# RE          35
# CR(PE)      19
# EX           1
# Name: cat, dtype: int64

# %%
values = [1, 35, 113, 200, 368, 437, 1643, 99, 0]
colors = ['r', 'r', 'r', 'r', 'r', 'g', "g", "grey", "grey"]
labels = [
    'EX: ausgestorben', 'RE: CH ausgestorben',
    'CR: v. aussterben bedroht', 'EN: stark gefährdet', 
    'VU: verletzlich',"NT: potenziell gef.",
    "LC: nicht gef.","DD: ungen. Daten","NE: nicht beurteilt"]


fig1, ax1 = plt.subplots(figsize=(7, 6))
fig1.subplots_adjust(0.3,0,1,1)
plt.pie(values, colors=colors, labels= values, counterclock=False,startangle=90)
plt.title('Gefährdung Gefässpflanzen, 2915 Arten')

total = sum(values)
plt.legend(
    loc='upper left',
    labels=['%s, %1.1f%%' % (
        l, (float(s) / total) * 100) for l, s in zip(labels, values)],
    
    bbox_to_anchor=(1.0, 0.5),
    bbox_transform=fig1.transFigure
)
plt.show()

# %%
values = [1, 35, 113, 200, 368, 437, 1643, 0, 0]
colors = ['r', 'r', 'r', 'r', 'r', 'g', "g", "grey", "grey"]
labels = [
    'EX: ausgestorben', 'RE: CH ausgestorben',
    'CR: v. aussterben bedroht', 'EN: stark gefährdet', 
    'VU: verletzlich',"NT: potenziell gef.",
    "LC: nicht gef.","DD: ungen. Daten","NE: nicht beurteilt"]


fig1, ax1 = plt.subplots(figsize=(7, 6))
fig1.subplots_adjust(0.3,0,1,1)
plt.pie(values, colors=colors, labels= values, counterclock=False,startangle=90)
plt.title('Gefährdung Gefässpflanzen, 2816 dokumentierte Arten')

total = sum(values)
plt.legend(
    loc='upper left',
    labels=['%s, %1.1f%%' % (
        l, (float(s) / total) * 100) for l, s in zip(labels, values)],
    
    bbox_to_anchor=(1.0, 0.5),
    bbox_transform=fig1.transFigure
)
plt.show()

# %%
#df_neu = df.copy()

df['stamm'] = 'Pflanze'

df.columns = ['id', '2', '3']

"""
df = df[[
    'stamm',
    'GROUP',
    'FAMILY',
    'GENUS',
    'SPECIES SSP',
    'Deutscher Name',
    'CAT',
    'Bemerkungen'
    
]]
"""

df.head()
