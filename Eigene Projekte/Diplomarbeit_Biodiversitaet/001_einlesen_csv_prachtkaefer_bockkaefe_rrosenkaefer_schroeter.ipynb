# %% [markdown]
# # MAZ Diplomarbeit - Biodiversität in der Schweiz#

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("01_source/xls_ch/prachtkaefer_bockkaeferrosenkaefer_schroeter_ch.csv")

# %%
df.head()
# Out:
#                        GROUP       ORDER       FAMILY          GENUS  \
# 0  4 familles de coléoptères  Coleoptera  Buprestidae     Acmaeodera
# 1  4 familles de coléoptères  Coleoptera  Buprestidae  Acmaeoderella
# 2  4 familles de coléoptères  Coleoptera  Buprestidae        Agrilus
# 3  4 familles de coléoptères  Coleoptera  Buprestidae        Agrilus
# 4  4 familles de coléoptères  Coleoptera  Buprestidae        Agrilus
#
#      SPECIES SSP                                    Scientific name  \
# 0        degener                 Acmaeodera degener (Scopoli, 1763)
# 1  flavofasciata  Acmaeoderella flavofasciata (Piller & Mitterpa...
# 2     angustulus                 Agrilus angustulus (Illiger, 1803)
# 3       antiquus               Agrilus antiquus Mulsant & Rey, 1863
# 4           ater                      Agrilus ater (Linnaeus, 1767)
#
#                         Deutscher Name CAT           Criteria  \
# 0        Gefleckter Eichen-Prachtkäfer  CR  B2ab(i,ii,iii,iv)
# 1  Weissgeschuppter Eichen-Prachtkäfer  VU    B2ab(ii,iii,iv)
# 2                                  NaN  LC                NaN
# 3                  Antiker Prachtkäfer  EN  B2ab(i,ii,iii,iv)
# 4        Gefleckter Pappel-Prachtkäfer  NT                NaN
#
#                                 Bemerkungen
# 0                              Urwaldrelikt
# 1  Nur in den Südalpen (Tessin, Graubünden)
# 2                                       NaN
# 3              Nur in den Südalpen (Tessin)
# 4                                       NaN

# %%
len (df)
# Out:
# 293

# %%
df.shape
# Out:
# (293, 10)

# %%
df["CAT"].value_counts()
# Out:
# LC    91
# NT    47
# EN    44
# VU    42
# DD    37
# CR    30
# RE     2
# Name: CAT, dtype: int64

# %%
df.head(1)
# Out:
#                        GROUP       ORDER       FAMILY       GENUS SPECIES SSP  \
# 0  4 familles de coléoptères  Coleoptera  Buprestidae  Acmaeodera     degener
#
#                       Scientific name                 Deutscher Name CAT  \
# 0  Acmaeodera degener (Scopoli, 1763)  Gefleckter Eichen-Prachtkäfer  CR
#
#             Criteria   Bemerkungen
# 0  B2ab(i,ii,iii,iv)  Urwaldrelikt

# %%
df.rename(columns={"GROUP":"group","ORDER": "order","FAMILY":"family","GENUS":"genus","SPECIES SSP":"species","Scientific name":"sc name","Deutscher Name":"dt name","CAT":"cat", "Criteria": "criteria", "Bemerkungen":"bemerkungen"},inplace=True)

# %%
df
# Out:
#                          group       order        family          genus  \
# 0    4 familles de coléoptères  Coleoptera   Buprestidae     Acmaeodera
# 1    4 familles de coléoptères  Coleoptera   Buprestidae  Acmaeoderella
# 2    4 familles de coléoptères  Coleoptera   Buprestidae        Agrilus
# 3    4 familles de coléoptères  Coleoptera   Buprestidae        Agrilus
# 4    4 familles de coléoptères  Coleoptera   Buprestidae        Agrilus
# 5    4 familles de coléoptères  Coleoptera   Buprestidae        Agrilus
# 6    4 familles de coléoptères  Coleoptera   Buprestidae        Agrilus
# 7    4 familles de coléoptères  Coleoptera   Buprestidae        Agrilus
# 8    4 familles de coléoptères  Coleoptera   Buprestidae        Agrilus
# 9    4 familles de coléoptères  Coleoptera   Buprestidae        Agrilus
# 10   4 familles de coléoptères  Coleoptera   Buprestidae        Agrilus
# 11   4 familles de coléoptères  Coleoptera   Buprestidae        Agrilus
# 12   4 familles de coléoptères  Coleoptera   Buprestidae        Agrilus
# 13   4 familles de coléoptères  Coleoptera   Buprestidae        Agrilus
# 14   4 familles de coléoptères  Coleoptera   Buprestidae        Agrilus
# 15   4 familles de coléoptères  Coleoptera   Buprestidae        Agrilus
# 16   4 familles de coléoptères  Coleoptera   Buprestidae        Agrilus
# 17   4 familles de coléoptères  Coleoptera   Buprestidae        Agrilus
# 18   4 familles de coléoptères  Coleoptera   Buprestidae        Agrilus
# 19   4 familles de coléoptères  Coleoptera   Buprestidae        Agrilus
# 20   4 familles de coléoptères  Coleoptera   Buprestidae        Agrilus
# 21   4 familles de coléoptères  Coleoptera   Buprestidae        Agrilus
# 22   4 familles de coléoptères  Coleoptera   Buprestidae        Agrilus
# 23   4 familles de coléoptères  Coleoptera   Buprestidae        Agrilus
# 24   4 familles de coléoptères  Coleoptera   Buprestidae        Agrilus
# 25   4 familles de coléoptères  Coleoptera   Buprestidae        Agrilus
# 26   4 familles de coléoptères  Coleoptera   Buprestidae        Agrilus
# 27   4 familles de coléoptères  Coleoptera   Buprestidae        Agrilus
# 28   4 familles de coléoptères  Coleoptera   Buprestidae        Agrilus
# 29   4 familles de coléoptères  Coleoptera   Buprestidae        Agrilus
# ..                         ...         ...           ...            ...
# 263  4 familles de coléoptères  Coleoptera  Cerambycidae        Tetrops
# 264  4 familles de coléoptères  Coleoptera  Cerambycidae      Tragosoma
# 265  4 familles de coléoptères  Coleoptera  Cerambycidae    Trichoferus
# 266  4 familles de coléoptères  Coleoptera  Cerambycidae    Xylotrechus
# 267  4 familles de coléoptères  Coleoptera  Cerambycidae    Xylotrechus
# 268  4 familles de coléoptères  Coleoptera    Cetoniidae        Cetonia
# 269  4 familles de coléoptères  Coleoptera    Cetoniidae       Gnorimus
# 270  4 familles de coléoptères  Coleoptera    Cetoniidae       Gnorimus
# 271  4 familles de coléoptères  Coleoptera    Cetoniidae      Osmoderma
# 272  4 familles de coléoptères  Coleoptera    Cetoniidae      Oxythyrea
# 273  4 familles de coléoptères  Coleoptera    Cetoniidae      Protaetia
# 274  4 familles de coléoptères  Coleoptera    Cetoniidae      Protaetia
# 275  4 familles de coléoptères  Coleoptera    Cetoniidae      Protaetia
# 276  4 familles de coléoptères  Coleoptera    Cetoniidae      Protaetia
# 277  4 familles de coléoptères  Coleoptera    Cetoniidae      Protaetia
# 278  4 familles de coléoptères  Coleoptera    Cetoniidae      Protaetia
# 279  4 familles de coléoptères  Coleoptera    Cetoniidae      Protaetia
# 280  4 familles de coléoptères  Coleoptera    Cetoniidae      Protaetia
# 281  4 familles de coléoptères  Coleoptera    Cetoniidae       Trichius
# 282  4 familles de coléoptères  Coleoptera    Cetoniidae       Trichius
# 283  4 familles de coléoptères  Coleoptera    Cetoniidae       Trichius
# 284  4 familles de coléoptères  Coleoptera    Cetoniidae      Tropinota
# 285  4 familles de coléoptères  Coleoptera    Cetoniidae         Valgus
# 286  4 familles de coléoptères  Coleoptera     Lucanidae        Aesalus
# 287  4 familles de coléoptères  Coleoptera     Lucanidae       Ceruchus
# 288  4 familles de coléoptères  Coleoptera     Lucanidae         Dorcus
# 289  4 familles de coléoptères  Coleoptera     Lucanidae        Lucanus
# 290  4 familles de coléoptères  Coleoptera     Lucanidae     Platycerus
# 291  4 familles de coléoptères  Coleoptera     Lucanidae     Platycerus
# 292  4 familles de coléoptères  Coleoptera     Lucanidae    Sinodendron
#
#               species                                            sc name  \
# 0             degener                 Acmaeodera degener (Scopoli, 1763)
# 1       flavofasciata  Acmaeoderella flavofasciata (Piller & Mitterpa...
# 2          angustulus                 Agrilus angustulus (Illiger, 1803)
# 3            antiquus               Agrilus antiquus Mulsant & Rey, 1863
# 4                ater                      Agrilus ater (Linnaeus, 1767)
# 5          auricollis              Agrilus auricollis Kiesenwetter, 1857
# 6            betuleti                 Agrilus betuleti (Ratzeburg, 1837)
# 7          biguttatus               Agrilus biguttatus (Fabricius, 1777)
# 8       convexicollis        Agrilus convexicollis L. Redtenbacher, 1849
# 9          cuprescens                 Agrilus cuprescens Ménétriés, 1832
# 10         cyanescens               Agrilus cyanescens (Ratzeburg, 1837)
# 11    derasofasciatus           Agrilus derasofasciatus Lacordaire, 1835
# 12            graecus                   Agrilus graecus Obenberger, 1914
# 13           graminis                Agrilus graminis Kiesenwetter, 1857
# 14            guerini                   Agrilus guerini Lacordaire, 1835
# 15         hastulifer               Agrilus hastulifer (Ratzeburg, 1837)
# 16           hyperici                  Agrilus hyperici (Creutzer, 1799)
# 17       integerrimus             Agrilus integerrimus (Ratzeburg, 1837)
# 18         laticornis                 Agrilus laticornis (Illiger, 1803)
# 19            lineola                 Agrilus lineola Kiesenwetter, 1857
# 20      obscuricollis           Agrilus obscuricollis Kiesenwetter, 1857
# 21         olivicolor              Agrilus olivicolor Kiesenwetter, 1857
# 22          pratensis                Agrilus pratensis (Ratzeburg, 1839)
# 23      pseudocyaneus           Agrilus pseudocyaneus Kiesenwetter, 1857
# 24             ribesi                      Agrilus ribesi Schaefer, 1946
# 25           roscidus                Agrilus roscidus Kiesenwetter, 1857
# 26            salicis                Agrilus salicis J. Frivaldsky, 1877
# 27           sinuatus                   Agrilus sinuatus (Olivier, 1790)
# 28         subauratus                  Agrilus subauratus (Gebler, 1833)
# 29        sulcicollis               Agrilus sulcicollis Lacordaire, 1835
# ..                ...                                                ...
# 263           starkii                    Tetrops starkii Chevrolat, 1859
# 264         depsarium               Tragosoma depsarium (Linnaeus, 1767)
# 265      holosericeus             Trichoferus holosericeus (Rossi, 1790)
# 266          antilope            Xylotrechus antilope (Schoenherr, 1817)
# 267          arvicola               Xylotrechus arvicola (Olivier, 1795)
# 268            aurata                    Cetonia aurata (Linnaeus, 1761)
# 269           nobilis                  Gnorimus nobilis (Linnaeus, 1758)
# 270        variabilis               Gnorimus variabilis (Linnaeus, 1758)
# 271           eremita                  Osmoderma eremita (Scopoli, 1763)
# 272           funesta         Oxythyrea funesta (Poda von Neuhaus, 1761)
# 273        aeruginosa                 Protaetia aeruginosa (Drury, 1770)
# 274           affinis                 Protaetia affinis (Andersch, 1797)
# 275         angustata                 Protaetia angustata (Germar, 1817)
# 276            cuprea                 Protaetia cuprea (Fabricius, 1775)
# 277           fieberi                   Protaetia fieberi (Kraatz, 1880)
# 278         marmorata              Protaetia marmorata (Fabricius, 1792)
# 279         metallica                 Protaetia metallica (Herbst, 1782)
# 280             morio                  Protaetia morio (Fabricius, 1781)
# 281         fasciatus                Trichius fasciatus (Linnaeus, 1758)
# 282          gallicus                     Trichius gallicus Dejean, 1821
# 283          sexualis                      Trichius sexualis Bedel, 1906
# 284             hirta           Tropinota hirta (Poda von Neuhaus, 1761)
# 285        hemipterus                 Valgus hemipterus (Linnaeus, 1758)
# 286     scarabaeoides               Aesalus scarabaeoides (Panzer, 1794)
# 287     chrysomelinus          Ceruchus chrysomelinus (Hochenwart, 1785)
# 288  parallelipipedus           Dorcus parallelipipedus (Linnaeus, 1758)
# 289            cervus                    Lucanus cervus (Linnaeus, 1758)
# 290            caprea                  Platycerus caprea (De Geer, 1774)
# 291        caraboides             Platycerus caraboides (Linnaeus, 1758)
# 292       cylindricum           Sinodendron cylindricum (Linnaeus, 1758)
#
#                                                dt name cat           criteria  \
# 0                        Gefleckter Eichen-Prachtkäfer  CR  B2ab(i,ii,iii,iv)
# 1                  Weissgeschuppter Eichen-Prachtkäfer  VU    B2ab(ii,iii,iv)
# 2                                                  NaN  LC                NaN
# 3                                  Antiker Prachtkäfer  EN  B2ab(i,ii,iii,iv)
# 4                        Gefleckter Pappel-Prachtkäfer  NT                NaN
# 5                          Rotblauer Ulmen-Prachtkäfer  NT                NaN
# 6                           Kleiner Birken-Prachtkäfer  VU  B2ab(i,ii,iii,iv)
# 7                   Zweigefleckter Eichen--Prachtkäfer  LC                NaN
# 8                          Schmaler Eschen-Prachtkäfer  LC                NaN
# 9                        Schmaler Brombeer-Prachtkäfer  LC                NaN
# 10                          Heckenkirschen-Prachtkäfer  LC                NaN
# 11                               Weinreben-Prachtkäfer  NT                NaN
# 12                                                 NaN  DD                NaN
# 13                    Haarstirniger Schmal-Prachtkäfer  NT                NaN
# 14                      Blauweisser Weiden-Prachtkäfer  DD                NaN
# 15                                                 NaN  DD                NaN
# 16                           Johanniskraut-Prachtkäfer  DD                NaN
# 17                              Seidelbast-Prachtkäfer  LC                NaN
# 18                                                 NaN  LC                NaN
# 19                                                 NaN  CR  B2ab(i,ii,iii,iv)
# 20                                                 NaN  NT                NaN
# 21                                                 NaN  LC                NaN
# 22                        Rotblauer Pappel-Prachtkäfer  NT                NaN
# 23                                                 NaN  DD                NaN
# 24                            Johannisbeer-Prachtkäfer  DD                NaN
# 25                       Schmaler Obstbaum-Prachtkäfer  DD                NaN
# 26                                                 NaN  DD                NaN
# 27                                Birnbaum-Prachtkäfer  NT                NaN
# 28                       Goldgrüner Weiden-Prachtkäfer  EN  B2ab(i,ii,iii,iv)
# 29                       Blaugrüner Eichen-Prachtkäfer  LC                NaN
# ..                                                 ...  ..                ...
# 263                                Starks Pflaumenbock  LC                NaN
# 264                                         Zottenbock  EN  B2ab(i,ii,iii,iv)
# 265                                                NaN  CR  B2ab(i,ii,iii,iv)
# 266   Zierlicher Holzwespenbock, Zierlicher Widderbock  NT                NaN
# 267  Sauerkirschen-Holzwespenbock, Sauerkirschen-Wi...  CR  B2ab(i,ii,iii,iv)
# 268       Goldglänzende Rosenkäfer, Gemeine Rosenkäfer  LC                NaN
# 269                             Grüner Edelscharrkäfer  NT                NaN
# 270  Veränderliche Edelscharrkäfer, Schwarzer Edelk...  EN  B2ab(i,ii,iii,iv)
# 271                               Eremit, Juchtenkäfer  CR  B2ab(i,ii,iii,iv)
# 272                                  Trauer-Rosenkäfer  NT                NaN
# 273                 Große Rosenkäfer, Großer Goldkäfer  EN  B2ab(i,ii,iii,iv)
# 274                                Ähnliche Rosenkäfer  EN  B2ab(i,ii,iii,iv)
# 275                                                NaN  CR  B2ab(i,ii,iii,iv)
# 276                                                NaN  LC                NaN
# 277                                                NaN  CR  B2ab(i,ii,iii,iv)
# 278    Bronzegrüne Rosenkäfer, Marmorierter Rosenkäfer  VU  B2ab(i,ii,iii,iv)
# 279                                                NaN  LC                NaN
# 280                                                NaN  EN  B2ab(i,ii,iii,iv)
# 281                             Gebänderte Pinselkäfer  LC                NaN
# 282                                                NaN  EN  B2ab(i,ii,iii,iv)
# 283                                                NaN  EN  B2ab(i,ii,iii,iv)
# 284                                                NaN  NT                NaN
# 285                                                NaN  LC                NaN
# 286                                       Kurzschröter  DD                NaN
# 287                                     Rindenschröter  EN         B2ab(i,ii)
# 288                                     Balkenschröter  LC                NaN
# 289                                        Hirschkäfer  VU           B2b(iii)
# 290                                Grosser Rehschröter  LC                NaN
# 291                                Kleiner Rehschröter  LC                NaN
# 292                                   Kopfhornschröter  NT                NaN
#
#                                            bemerkungen
# 0                                         Urwaldrelikt
# 1             Nur in den Südalpen (Tessin, Graubünden)
# 2                                                  NaN
# 3                         Nur in den Südalpen (Tessin)
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12         Einzige Fundmeldung in der Schweiz von 2005
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                        Nur in den Südalpen (Tessin)
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26         Einzige Fundmeldung in der Schweiz von 1975
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 263                                                NaN
# 264                                       Urwaldrelikt
# 265                                                NaN
# 266                                                NaN
# 267                                                NaN
# 268                                                NaN
# 269                                                NaN
# 270                                                NaN
# 271                                       Urwaldrelikt
# 272                                                NaN
# 273                                                NaN
# 274  Urwaldrelikt, nur in den Südalpen (Tessin, Gra...
# 275                       Nur in den Südalpen (Tessin)
# 276                                                NaN
# 277                    Letzter Schweizer Nachweis 1997
# 278                                                NaN
# 279                                                NaN
# 280           Nur in den Südalpen (Tessin, Graubünden)
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
# 284                                                NaN
# 285                                                NaN
# 286                                                NaN
# 287                                       Urwaldrelikt
# 288                                                NaN
# 289                                Langer Lebenszyklus
# 290                                                NaN
# 291                                                NaN
# 292                                                NaN
#
# [293 rows x 10 columns]

# %%
df.pop("criteria")
df.pop("genus")
df.pop("species")
# Out:
# 0               degener
# 1         flavofasciata
# 2            angustulus
# 3              antiquus
# 4                  ater
# 5            auricollis
# 6              betuleti
# 7            biguttatus
# 8         convexicollis
# 9            cuprescens
# 10           cyanescens
# 11      derasofasciatus
# 12              graecus
# 13             graminis
# 14              guerini
# 15           hastulifer
# 16             hyperici
# 17         integerrimus
# 18           laticornis
# 19              lineola
# 20        obscuricollis
# 21           olivicolor
# 22            pratensis
# 23        pseudocyaneus
# 24               ribesi
# 25             roscidus
# 26              salicis
# 27             sinuatus
# 28           subauratus
# 29          sulcicollis
#              ...
# 263             starkii
# 264           depsarium
# 265        holosericeus
# 266            antilope
# 267            arvicola
# 268              aurata
# 269             nobilis
# 270          variabilis
# 271             eremita
# 272             funesta
# 273          aeruginosa
# 274             affinis
# 275           angustata
# 276              cuprea
# 277             fieberi
# 278           marmorata
# 279           metallica
# 280               morio
# 281           fasciatus
# 282            gallicus
# 283            sexualis
# 284               hirta
# 285          hemipterus
# 286       scarabaeoides
# 287       chrysomelinus
# 288    parallelipipedus
# 289              cervus
# 290              caprea
# 291          caraboides
# 292         cylindricum
# Name: species, Length: 293, dtype: object

# %%
df.head()
# Out:
#                        group       order       family  \
# 0  4 familles de coléoptères  Coleoptera  Buprestidae
# 1  4 familles de coléoptères  Coleoptera  Buprestidae
# 2  4 familles de coléoptères  Coleoptera  Buprestidae
# 3  4 familles de coléoptères  Coleoptera  Buprestidae
# 4  4 familles de coléoptères  Coleoptera  Buprestidae
#
#                                              sc name  \
# 0                 Acmaeodera degener (Scopoli, 1763)
# 1  Acmaeoderella flavofasciata (Piller & Mitterpa...
# 2                 Agrilus angustulus (Illiger, 1803)
# 3               Agrilus antiquus Mulsant & Rey, 1863
# 4                      Agrilus ater (Linnaeus, 1767)
#
#                                dt name cat  \
# 0        Gefleckter Eichen-Prachtkäfer  CR
# 1  Weissgeschuppter Eichen-Prachtkäfer  VU
# 2                                  NaN  LC
# 3                  Antiker Prachtkäfer  EN
# 4        Gefleckter Pappel-Prachtkäfer  NT
#
#                                 bemerkungen
# 0                              Urwaldrelikt
# 1  Nur in den Südalpen (Tessin, Graubünden)
# 2                                       NaN
# 3              Nur in den Südalpen (Tessin)
# 4                                       NaN

# %%
df['einteilung'] = 'Insekten'
df['untergruppe'] = 'Pracht-,Bock-,Rosenkäfer,Schröter'

# %%
df.head()
# Out:
#                        group       order       family  \
# 0  4 familles de coléoptères  Coleoptera  Buprestidae
# 1  4 familles de coléoptères  Coleoptera  Buprestidae
# 2  4 familles de coléoptères  Coleoptera  Buprestidae
# 3  4 familles de coléoptères  Coleoptera  Buprestidae
# 4  4 familles de coléoptères  Coleoptera  Buprestidae
#
#                                              sc name  \
# 0                 Acmaeodera degener (Scopoli, 1763)
# 1  Acmaeoderella flavofasciata (Piller & Mitterpa...
# 2                 Agrilus angustulus (Illiger, 1803)
# 3               Agrilus antiquus Mulsant & Rey, 1863
# 4                      Agrilus ater (Linnaeus, 1767)
#
#                                dt name cat  \
# 0        Gefleckter Eichen-Prachtkäfer  CR
# 1  Weissgeschuppter Eichen-Prachtkäfer  VU
# 2                                  NaN  LC
# 3                  Antiker Prachtkäfer  EN
# 4        Gefleckter Pappel-Prachtkäfer  NT
#
#                                 bemerkungen einteilung  \
# 0                              Urwaldrelikt   Insekten
# 1  Nur in den Südalpen (Tessin, Graubünden)   Insekten
# 2                                       NaN   Insekten
# 3              Nur in den Südalpen (Tessin)   Insekten
# 4                                       NaN   Insekten
#
#                          untergruppe
# 0  Pracht-,Bock-,Rosenkäfer,Schröter
# 1  Pracht-,Bock-,Rosenkäfer,Schröter
# 2  Pracht-,Bock-,Rosenkäfer,Schröter
# 3  Pracht-,Bock-,Rosenkäfer,Schröter
# 4  Pracht-,Bock-,Rosenkäfer,Schröter

# %%
df["cat"].value_counts()
# Out:
# LC    91
# NT    47
# EN    44
# VU    42
# DD    37
# CR    30
# RE     2
# Name: cat, dtype: int64

# %%
values = [0, 2, 30, 44, 42, 47, 91, 37, 0]
colors = ['r', 'r', 'r', 'r', 'r', 'g', "g", "grey", "grey"]
labels = [
    'EX: ausgestorben', 'RE: CH ausgestorben',
    'CR: v. aussterben bedroht', 'EN: stark gefährdet', 
    'VU: verletzlich',"NT: potenziell gef.",
    "LC: nicht gef.","DD: ungen. Daten","NE: nicht beurteilt"]


fig1, ax1 = plt.subplots(figsize=(7, 6))
fig1.subplots_adjust(0.3,0,1,1)
plt.pie(values, colors=colors, labels= values, counterclock=False,startangle=90)
plt.title('Gefährdung Pracht-, Rosen-, Bockkäfer,Schröter, 293 Arten')

total = sum(values)
plt.legend(
    loc='upper left',
    labels=['%s, %1.1f%%' % (
        l, (float(s) / total) * 100) for l, s in zip(labels, values)],
    
    bbox_to_anchor=(1.0, 0.5),
    bbox_transform=fig1.transFigure
)
plt.show()

# %%
values = [0, 2, 30, 44, 42, 47, 91, 0, 0]
colors = ['r', 'r', 'r', 'r', 'r', 'g', "g", "grey", "grey"]
labels = [
    'EX: ausgestorben', 'RE: CH ausgestorben',
    'CR: v. aussterben bedroht', 'EN: stark gefährdet', 
    'VU: verletzlich',"NT: potenziell gef.",
    "LC: nicht gef.","DD: ungen. Daten","NE: nicht beurteilt"]


fig1, ax1 = plt.subplots(figsize=(7, 6))
fig1.subplots_adjust(0.3,0,1,1)
plt.pie(values, colors=colors, labels= values, counterclock=False,startangle=90)
plt.title('Gefährdung Pracht-, Rosen-, Bockkäfer,Schröter, 256 dokumentierte Arten')

total = sum(values)
plt.legend(
    loc='upper left',
    labels=['%s, %1.1f%%' % (
        l, (float(s) / total) * 100) for l, s in zip(labels, values)],
    
    bbox_to_anchor=(1.0, 0.5),
    bbox_transform=fig1.transFigure
)
plt.show()
