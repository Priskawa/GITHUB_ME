# %% [markdown]
# # Lobbying EU #

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df16 = pd.read_excel("Lobbying in EU durch CH-Firmen_16.xlsx")

# %%
df16.head()
# Out:
#                  Transparenz Register EU Januar 2016 Unnamed: 1 Unnamed: 2  \
# 0                                               Name         MA        FTE
# 1  European Federation of Pharmaceutical Industri...         27      14.75
# 2                              Dow Europe GmbH (Dow)         11        6.5
# 3                          Novartis International AG         10       5.25
# 4                          Syngenta International AG          5       2.25
#
#         Unnamed: 3       Unnamed: 4  Unnamed: 5
# 0  Ausgaben (min.)  Ausgaben (max.)         NaN
# 1          5071000          5071000   5780940.0
# 2          3750000          3999999         NaN
# 3          1750000          1999999         NaN
# 4          1250000          1499999         NaN

# %%
len (df16)
# Out:
# 175

# %%
df16.pop("Unnamed: 1")
df16.pop("Unnamed: 2")
df16.pop("Unnamed: 3")
df16.pop("Unnamed: 4")
df16.pop("Unnamed: 5")

df16.head(2)
# Out:
#                  Transparenz Register EU Januar 2016
# 0                                               Name
# 1  European Federation of Pharmaceutical Industri...

# %%
df19 = pd.read_excel("Lobbying in EU durch CH-Firmen_19.xlsx")

# %%
df19.head()
# Out:
#   Transparenz Register EU (Stand Januar 2019) Unnamed: 1   Unnamed: 2  \
# 0                                Organisation  Hauptsitz  Mitarbeiter
# 1                       Dow Europe GmbH (Dow)     Horgen           10
# 2                   Novartis International AG      Basel           14
# 3                   Syngenta International AG      Basel            5
# 4               Credit Suisse Group AG (CSAG)     Zurich            7
#
#         Unnamed: 3       Unnamed: 4
# 0  Ausgaben (min.)  Ausgaben (max.)
# 1          3000000          3249999
# 2          2250000          2499999
# 3          1500000          1749000
# 4          1500000          1749000

# %%
len (df19)
# Out:
# 263

# %%
df19.pop("Unnamed: 1")
df19.pop("Unnamed: 2")
df19.pop("Unnamed: 3")
df19.pop("Unnamed: 4")

df19.head(2)
# Out:
#   Transparenz Register EU (Stand Januar 2019)
# 0                                Organisation
# 1                       Dow Europe GmbH (Dow)

# %%
#df_1 = df16.merge(df19, how='inner', left_on='Transparenz Register EU Januar 2016', right_on="Transparenz Register EU (Stand Januar 2019)")
#df_1.head(10)

# %%
pd.concat([df16, df19], ignore_index=True, axis=1)
# Out:
#                                                      0  \
# 0                                                 Name
# 1    European Federation of Pharmaceutical Industri...
# 2                                Dow Europe GmbH (Dow)
# 3                            Novartis International AG
# 4                            Syngenta International AG
# 5               Philip Morris International Inc. (PMI)
# 6                                   UBS Group AG (UBS)
# 7                        Credit Suisse Group AG (CSAG)
# 8                     F. Hoffmann-La Roche Ltd (Roche)
# 9                         Swiss Federal Railways (SBB)
# 10                                 KPMG EMA (KPMG EMA)
# 11                             Alcoa Europe SA (Alcoa)
# 12   International Road Transport Union Permanent D...
# 13                Archer Daniels Midland Company (ADM)
# 14                        Zurich Insurance Company Ltd
# 15                       eBay EU liaison office (eBay)
# ...
