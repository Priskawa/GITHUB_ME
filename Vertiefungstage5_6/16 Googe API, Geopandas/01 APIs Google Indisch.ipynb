# %% [markdown]
# # APIs und Authentifikation (Google API)

# %% [markdown]
# Wir haben uns vor langer, langer Zeit die Erdbeben-Applikation angeschaut. Die Nutzung ist zwar begrenzt, doch es für deren Nutzung keine weitere Zulassung notwendig. Das ist bei den meisten anderen APIs nicht der Fall. In der Regel verlangen die Besitzer einer API Authentifikation der Nutzer. So können sie kontrollieren, wer wieviel nutzt. Denn auch eine API-Abfrage beansprucht Rechenkraft. Bei Millionen Abfragen kann das schnell ins Geld gehen. Es gibt dabei verschiedene API-Typen: REST, SOAP, XML-RCP oder JSON-RPC. Was die verschiedenen Vorteile dieser API-Technologien sind, schlägt ihr am besten nach. Die gängigsten sind heute REST und SOAP. Die trifft man immer wieder.

# %% [markdown]
# Wie man sich authentifiziert, wollen wir uns nun gemeinsam anschauen. Wir tun das mit der Google Maps API. Zu allererst müssen wir eine Key kreieren. Dafür brauchen wir eine Gmail-Konto und eine Kreditkarte. Wir werden keinen Rappen ausgeben, die erste 100'000 Aufrufe sind gratis. Die Kreditkarte ist trotzdem nötig. Als erstes besuchen wir [also die Google-Maps-Plattform](https://cloud.google.com/maps-platform).

# %% [markdown]
# ## Die Google API
# Die API kann man für verschiedene Sachen verwenden: Um Distanzen zu berechnen, um Standorte mit Geo-Daten auszustatten, oder um Standorte zu suchen. Natürlich nicht einzelne Standorte, sondern ganz viele. In diesem Beispiel werden wir uns bestimmte Standorte suchen.

# %% [markdown]
# Nachdem ihr Euch oben bei Google angemeldet habt, müsst ihr eine API Key generieren und abspeichern. Nun gehen wir nur Places API und Places Search. Das [ist hier](https://developers.google.com/places/web-service/intro).

# %% [markdown]
# Um Eure API keys zu finden, geht ihr zu API & Services, Credentials. [Hier](https://console.cloud.google.com/apis/credentials?project=clear-canyon-166711)

# %% [markdown]
# ### Das indische Restaurant mit den meisten Sternen bei Google Maps?

# %% [markdown]
# Wir werden mir der Textsearch-Option arbeiten: ```https://maps.googleapis.com/maps/api/place/textsearch/output?parameters```. Wir geben ein:
# - https://maps.googleapis.com/maps/api/place/textsearch/json
# - query=italienische+restaurants+in+zurich
# - fields=formatted_address,name,rating,opening_hours,pagetoken
# - key=XXXXXX

# %%
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"
query = "query=indische+restaurants+in+zurich&"
fields = "fields=formatted_address,name,rating,opening_hours,pagetoken&"
locationbias = "locationbias=point:lat,lng&"
key = "key=AIzaSyCFjPQnrrWXNdHh8KW4qqaUammFlkG83Io"

# %%
api_query = url+query+fields+locationbias+key

# %%
api_query
# Out:
# 'https://maps.googleapis.com/maps/api/place/textsearch/json?query=indische+restaurants+in+zurich&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyCFjPQnrrWXNdHh8KW4qqaUammFlkG83Io'

# %% [markdown]
# importieren wir requests

# %%
import requests
# Out:
# /Users/priskawa/.virtualenvs/dataviz/lib/python3.7/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.23) or chardet (2.3.0) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
r = requests.get(api_query)
result = r.json()

# %%
len(result)
# Out:
# 4

# %%
for key in result:
    print(key)
# Out:
# html_attributions
# next_page_token
# results
# status

# %%
result['results'][0]['geometry']['location']
# Out:
# {'lat': 47.4068396, 'lng': 8.5482176}

# %%
new_lst = []

for elem in result['results']:
    address = elem['formatted_address']
    name = elem['name']
    rating = elem['rating']
    lat = elem['geometry']['location']['lat']
    long = elem['geometry']['location']['lng']
    
    mini_dict = {'Addresse': address, 
                 'Name': name,
                 'Rating': rating,
                 'Lat':lat,
                 'Lng':long}
    
    new_lst.append(mini_dict)

# %%
import pandas as pd

# %%
pd.DataFrame(new_lst)
# Out:
#                                              Addresse        Lat       Lng  \
# 0   Schaffhauserstrasse 306, 8050 Zürich, Switzerland  47.406840  8.548218
# 1         Klingenstrasse 33, 8005 Zürich, Switzerland  47.382002  8.533625
# 2         Seefeldstrasse 96, 8008 Zürich, Switzerland  47.359788  8.552528
# 3     Wallisellenstrasse 11, 8050 Zürich, Switzerland  47.410530  8.548490
# 4   Tadka Indisches Restaurant, Quellenstrasse 49,...  47.386272  8.528704
# 5      Hofwiesenstrasse 188, 8057 Zürich, Switzerland  47.401948  8.535317
# 6       Zypressenstrasse 52, 8004 Zürich, Switzerland  47.377474  8.513121
# 7   Schaffhauserstrasse 410, 8050 Zürich, Switzerland  47.414826  8.545811
# 8     Stauffacherstrasse 27, 8004 Zürich, Switzerland  47.373018  8.528926
# 9    Schaffhauserstrasse 32, 8006 Zürich, Switzerland  47.390330  8.539215
# 10                Rigipl. 1, 8006 Zürich, Switzerland  47.384879  8.548608
# 11          Langstrasse 213, 8005 Zürich, Switzerland  47.383132  8.530098
# 12           Predigerpl. 34, 8001 Zürich, Switzerland  47.373615  8.545746
# 13   Pfingstweidstrasse 104, 8005 Zürich, Switzerland  47.390856  8.509017
# 14  Meinrad-Lienert-Strasse 27, 8003 Zürich, Switz...  47.375171  8.517364
# 15      Seebacherstrasse 77, 8052 Zürich, Switzerland  47.422447  8.540617
# 16        Kanzleistrasse 78, 8004 Zürich, Switzerland  47.375703  8.524385
# 17        Zollikerstrasse 1, 8008 Zürich, Switzerland  47.364218  8.554734
# 18        Seefeldstrasse 7A, 8008 Zürich, Switzerland  47.365034  8.548724
# 19     Uetlibergstrasse 166, 8045 Zürich, Switzerland  47.359289  8.516227
#
#                                 Name  Rating
# 0                      Tamarind Hill     4.5
# 1                             Vulkan     4.1
# 2                       Tandoori BBQ     4.3
# 3                            Malabar     4.3
# 4                              Tadka     4.3
# 5                             Kerala     4.4
# 6            DelhiHouse of Bestcurry     4.2
# 7                      Indian Palace     4.0
# 8                             Masala     4.0
# 9                              Thali     4.1
# 10                     Cheti's Curry     4.5
# 11                       Thali House     4.0
# 12                        New Bombay     4.5
# 13                  naanu Take & Eat     4.4
# 14                     Namaste india     4.2
# 15                      Tandoor Haus     4.2
# 16                             Kobal     4.4
# 17  DARBAR INDIAN CUISINE RESTAURANT     4.4
# 18                           Cheti's     4.2
# 19                             Swaad     3.9

# %% [markdown]
# Aber, das sind nur 20. Wir wollen mehr. Dafür müssen wir mit diesem Nexttoken arbeiten.

# %%
import time

# %%
new_list = []

url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"
query = "query=indische+restaurants+in+zurich&"
fields = "fields=formatted_address,name,rating,opening_hours,pagetoken&"
locationbias = "locationbias=point:lat,lng&"
key = "key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&"
pagetoken = ''

result = range(4)
while len(result) > 3: 
    
    print(len(result))

    api_query = url+query+fields+locationbias+key+pagetoken
    print(api_query)
    time.sleep(2)
    r = requests.get(api_query)
    result = r.json()
    print(len(result))
    
    for elem in result['results']:
        address = elem['formatted_address']
        name = elem['name']
        rating = elem['rating']
        lat = elem['geometry']['location']['lat']
        long = elem['geometry']['location']['lng']
    
        mini_dict = {'Addresse': address, 
                     'Name': name,
                     'Rating': rating,
                     'Lat':lat,
                     'Lng':long}
    
        new_list.append(mini_dict)
        
    
    if len(result) > 3:
        pagetoken = 'pagetoken='+result['next_page_token'] 
    else:
        break
# Out:
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=indische+restaurants+in+zurich&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 4
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=indische+restaurants+in+zurich&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&pagetoken=CuQD0wEAAFbeIuXN-Qp7UOM-AtcrGU3k_e4b7JbjbkVoDNLqgP6HG-RJso7zC0dVQ8NUvtdrOzPfqBOstep7d1kpb7X7wk-1W-68zd2btX7JX4Q-txoExboQatbl3a9y5urGRoyjoVGclCYl7vpTySH1po-sdYfWjPzj77CdzzQwrxiF1arMFlDIL38GifGbqjuwhqHmwJc3UggHke7kU7BEViEKz2EGEmsM_Q7GKP77Qwy9TJ-tFog9_CPMlvAD7-B0iGJA7v730xSzrizoZHoxZX5y9KN0GLOyxbbP2Y_3JHJEH1FbwzdN6Yd3EEKW5a5TmX9P8S-_dUnlaCVdOj7GM_gVLXc9s_xC8_uM7HAfsLKydMDEBqftVBx8H8qRDzUrl1_QmK5St0e85TJf2fJaCTEqWRyxTot-9PZjGl1YEt9M15YIWsbNN4QwE1zczXJQp8mvKi39mr5SkwMwtxbP249BBpTlUfjRwiqo1KVdlEkFogAoieiVNlM3CBD7zwX6faE-sSoCGw8GZTT5bZywOl8Y-qXmR0Mjdr0KDyxlN5k1pSWMwWK3q29mDtqpfFpAsHPw6MIXvKJTuse-VTtoiH5jfC5O-GVtJUhVb3-47_YLtZskL_QdqGG8ul4795dFg_9uZRIQwBX3S3-r13F1QkPNo1mz0RoUwh-gOWQVt0vXz6-VwJSw4A0D1as
# 3

# %%
pd.DataFrame(new_list)
# Out:
#                                              Addresse        Lat       Lng  \
# 0   Schaffhauserstrasse 306, 8050 Zürich, Switzerland  47.406840  8.548218
# 1         Klingenstrasse 33, 8005 Zürich, Switzerland  47.382002  8.533625
# 2         Seefeldstrasse 96, 8008 Zürich, Switzerland  47.359788  8.552528
# 3     Wallisellenstrasse 11, 8050 Zürich, Switzerland  47.410530  8.548490
# 4   Tadka Indisches Restaurant, Quellenstrasse 49,...  47.386272  8.528704
# 5      Hofwiesenstrasse 188, 8057 Zürich, Switzerland  47.401948  8.535317
# 6       Zypressenstrasse 52, 8004 Zürich, Switzerland  47.377474  8.513121
# 7   Schaffhauserstrasse 410, 8050 Zürich, Switzerland  47.414826  8.545811
# 8     Stauffacherstrasse 27, 8004 Zürich, Switzerland  47.373018  8.528926
# 9    Schaffhauserstrasse 32, 8006 Zürich, Switzerland  47.390330  8.539215
# 10                Rigipl. 1, 8006 Zürich, Switzerland  47.384879  8.548608
# 11          Langstrasse 213, 8005 Zürich, Switzerland  47.383132  8.530098
# 12           Predigerpl. 34, 8001 Zürich, Switzerland  47.373615  8.545746
# 13   Pfingstweidstrasse 104, 8005 Zürich, Switzerland  47.390856  8.509017
# 14  Meinrad-Lienert-Strasse 27, 8003 Zürich, Switz...  47.375171  8.517364
# 15      Seebacherstrasse 77, 8052 Zürich, Switzerland  47.422447  8.540617
# 16        Kanzleistrasse 78, 8004 Zürich, Switzerland  47.375703  8.524385
# 17        Zollikerstrasse 1, 8008 Zürich, Switzerland  47.364218  8.554734
# 18        Seefeldstrasse 7A, 8008 Zürich, Switzerland  47.365034  8.548724
# 19     Uetlibergstrasse 166, 8045 Zürich, Switzerland  47.359289  8.516227
# 20          Kanonengasse 19, 8004 Zürich, Switzerland  47.377685  8.529521
# 21       Sihlfeldstrasse 45, 8003 Zürich, Switzerland  47.374745  8.516792
# 22     Witikonerstrasse 375, 8053 Zürich, Switzerland  47.359330  8.591961
# 23     Limmattalstrasse 252, 8049 Zürich, Switzerland  47.402748  8.492575
# 24             Mühlegasse 5, 8001 Zürich, Switzerland  47.374439  8.543570
# 25        Hönggerstrasse 25, 8037 Zürich, Switzerland  47.390972  8.526495
# 26      Beckenhofstrasse 16, 8006 Zürich, Switzerland  47.383323  8.541905
# 27         Zwinglistrasse 3, 8004 Zürich, Switzerland  47.377810  8.529577
# 28     Binzmühlestrasse 104, 8050 Zürich, Switzerland  47.413524  8.538773
# 29      Ellen-Widmann-Weg 6, 8050 Zürich, Switzerland  47.414887  8.539518
# 30          Josefstrasse 91, 8005 Zürich, Switzerland  47.383009  8.530692
# 31         Richtipl. 3, 8304 Wallisellen, Switzerland  47.409918  8.595613
# 32     Wehntalerstrasse 544, 8046 Zürich, Switzerland  47.419415  8.506253
# 33          Kalchengasse 12, 8302 Kloten, Switzerland  47.452783  8.582740
# 34      Thurgauerstrasse 32, 8050 Zürich, Switzerland  47.413183  8.552203
# 35   Stampfenbachstrasse 32, 8006 Zürich, Switzerland  47.379333  8.543476
# 36         Josefstrasse 146, 8005 Zürich, Switzerland  47.384797  8.527722
# 37  Badenerstrasse 663, 8048 Zürich Altstetten, Sw...  47.387284  8.487503
# 38         Zweierstrasse 55, 8004 Zürich, Switzerland  47.372427  8.524276
# 39           Mattengasse 29, 8005 Zürich, Switzerland  47.382890  8.530727
#
#                                     Name  Rating
# 0                          Tamarind Hill     4.5
# 1                                 Vulkan     4.1
# 2                           Tandoori BBQ     4.3
# 3                                Malabar     4.3
# 4                                  Tadka     4.3
# 5                                 Kerala     4.4
# 6                DelhiHouse of Bestcurry     4.2
# 7                          Indian Palace     4.0
# 8                                 Masala     4.0
# 9                                  Thali     4.1
# 10                         Cheti's Curry     4.5
# 11                           Thali House     4.0
# 12                            New Bombay     4.5
# 13                      naanu Take & Eat     4.4
# 14                         Namaste india     4.2
# 15                          Tandoor Haus     4.2
# 16                                 Kobal     4.4
# 17      DARBAR INDIAN CUISINE RESTAURANT     4.4
# 18                               Cheti's     4.2
# 19                                 Swaad     3.9
# 20                                  Cima     4.5
# 21                         Sher-E-Punjab     3.9
# 22                        Crown of India     4.0
# 23                              Maharani     3.7
# 24                            Kormasutra     3.7
# 25                            Taj Palace     3.1
# 26                          Curry Corner     4.7
# 27                            Raja Bongo     4.5
# 28                           Kurry World     4.4
# 29                               Namaste     4.4
# 30                              Ali Baba     4.2
# 31                                 Sahar     4.3
# 32        Indian Restaurant Spice Garden     3.8
# 33                      Flavour of India     3.9
# 34  Kurry World -Hong Kong Food Paradise     4.3
# 35                        Bombay Karachi     3.7
# 36                        Friends Corner     4.5
# 37          Curry Queen Take Away Zürich     4.4
# 38                                 Neela     4.6
# 39                 Don't Worry Eat Curry     4.6

# %% [markdown]
# Das ist leider nicht zufriedenstellend, denn offenbar begrenzt sich Google selber. Wir müssen die nexttoken Suche mit einer Suche nach Städten erweitern. Suchen wir "schweizer städte .csv" bei Google.

# %% [markdown]
# ## Ergänzung Schweizer Städte

# %%
t = pd.read_html("https://de.wikipedia.org/wiki/Liste_der_St%C3%A4dte_in_der_Schweiz#St%C3%A4dte_mit_mindestens_10'000_Einwohnern")

# %%
t[0]
# Out:
#         0                       1        2        3        4        5  \
# 0    Rang                    Name   F 1995   F 2000   F 2005   F 2010
# 1      1.                Zürich 1  343'869  337'900  347'517  372'857
# 2      2.                  Genf 1  173'549  174'999  178'722  187'470
# 3      3.                 Basel 1  174'007  166'009  163'930  163'216
# 4      4.                  Bern 1  127'469  122'484  122'178  124'381
# 5      5.              Lausanne 1  115'878  114'889  117'388  127'821
# 6      6.            Winterthur 1   87'654   88'767   93'546  101'308
# 7      7.                Luzern 1   58'847   57'023   57'533   77'491
# 8      8.            St. Gallen 1   71'877   69'836   70'316   72'959
# 9      9.                Lugano 1   26'000   25'872   49'223   54'667
# 10    10.           Biel/Bienne 1   50'733   48'840   48'735   51'203
# 11    11.                  Thun 1   39'094   39'981   41'138   42'623
# 12    12.                   Köniz   36'335   37'196   37'250   38'823
# 13    13.     La Chaux-de-Fonds 1   37'375   36'747   36'809   37'504
# 14    14.              Freiburg 1   32'501   31'691   33'008   34'897
# 15    15.          Schaffhausen 1   34'073   33'274   33'569   34'943
# 16    16.                  Chur 1   30'091   31'310   32'409   33'756
# 17    17.                 Vernier   28'423   28'727   30'020   32'844
# 18    18.             Neuenburg 1   31'768   31'639   32'117   33'815
# 19    19.                   Uster   26'139   27'893   29'855   32'265
# 20    20.                Sitten 1   26'065   27'145   28'510   30'363
# 21    21.                   Lancy   25'043   25'479   26'905   28'631
# 22    22.     Yverdon-les-Bains 1   23'234   23'144   24'415   27'511
# 23    23.                   Emmen   26'746   26'628   26'906   28'031
# 24    24.                   Zug 1   22'778   22'710   24'179   26'327
# 25    25.                  Kriens   24'156   24'394   25'336   26'324
# 26    26.   Rapperswil-Jona 1 / 3   15'742   16'733   17'689   26'212
# 27    27.               Dübendorf   20'906   22'011   22'707   24'831
# 28    28.                Dietikon   20'953   21'060   22'178   23'624
# 29    29.                Montreux   20'982   21'969   23'023   24'579
# ..    ...                     ...      ...      ...      ...      ...
# 119  119.                    Belp    8'334    8'994    9'565   10'221
# 120  120.                    Worb   11'100   10'779   11'137   11'364
# 121  121.             Bassersdorf    6'808    7'373    9'314   11'077
# 122  122.                    Arth    9'288    9'963    9'925   10'699
# 123  123.               Pfäffikon    8'947    9'332    9'951   10'627
# 124  124.            Altstätten 1   10'293   10'283   10'547   10'819
# 125  125.                 Ittigen   10'836   10'997   10'839   10'946
# 126  126.              Zofingen 1    8'513    8'601   10'228   10'803
# 127  127.      La Tour-de-Peilz 1   10'182   10'118   10'474   10'786
# 128  128.                   Davos   11'232   12'013   10'817   11'166
# 129  129.         Chêne-Bougeries    9'624    9'709   10'061   10'400
# 130  130.                 Brugg 1    9'208    9'162    9'037   10'386
# 131  131.            Spreitenbach    8'797    9'045    9'982   10'465
# 132  132.              Weinfelden    9'301    9'366    9'519   10'383
# 133  133.              Veyrier GE    7'756    8'986    9'553   10'003
# 134  134.                 Oberwil    8'843    9'433    9'962   10'442
# 135  135.       Val-de-Travers NE   10'896   10'794   10'834   10'812
# 136  136.                  Hinwil    8'705    9'081    9'761   10'379
# 137  137.                  Möhlin    7'832    8'292    8'884   10'023
# 138  138.              Romanshorn    7'199    8'432    9'008    9'711
# 139  139.               Männedorf    7'699    8'244    9'582   10'442
# 140  140.                Le Locle   10'977   10'349   10'226   10'049
# 141  141.  Neuhausen am Rheinfall   10'626   10'062    9'880   10'185
# 142  142.                  Flawil    9'154    9'320    9'971   10'150
# 143  143.              Birsfelden   11'049   10'243   10'240   10'352
# 144  144.         Plan-les-Ouates    8'974    9'265    9'548    9'807
# 145  145.                Sarnen 2    8'799    9'218    9'445    9'891
# 146  146.                   Aesch    9'555    9'801    9'880   10'219
# 147  147.              Zollikofen    8'817    9'101    9'548    9'690
# 148  148.                   Risch    6'073    7'218    8'419    9'085
#
#            6                 7
# 0     F 2015            Kanton
# 1    396'027            Zürich
# 2    194'565              Genf
# 3    175'131       Basel-Stadt
# 4    140'634              Bern
# 5    135'629             Waadt
# 6    106'778            Zürich
# 7     81'284            Luzern
# 8     75'310        St. Gallen
# 9     63'668            Tessin
# 10    53'667              Bern
# 11    43'303              Bern
# 12    39'998              Bern
# 13    39'027         Neuenburg
# 14    38'288          Freiburg
# 15    35'927      Schaffhausen
# 16    34'547        Graubünden
# 17    34'477              Genf
# 18    33'641         Neuenburg
# 19    33'412            Zürich
# 20    33'296            Wallis
# 21    30'919              Genf
# 22    29'406             Waadt
# 23    29'292            Luzern
# 24    28'603               Zug
# 25    27'229            Luzern
# 26    26'875        St. Gallen
# 27    26'759            Zürich
# 28    26'277            Zürich
# 29    26'208             Waadt
# ..       ...               ...
# 119   11'466              Bern
# 120   11'423              Bern
# 121   11'404            Zürich
# 122   11'301            Schwyz
# 123   11'275            Zürich
# 124   11'273        St. Gallen
# 125   11'250              Bern
# 126   11'210            Aargau
# 127   11'197             Waadt
# 128   11'136        Graubünden
# 129   11'105              Genf
# 130   11'104            Aargau
# 131   11'040            Aargau
# 132   11'039           Thurgau
# 133   10'999              Genf
# 134   10'917  Basel-Landschaft
# 135   10'854         Neuenburg
# 136   10'799            Zürich
# 137   10'746            Aargau
# 138   10'659           Thurgau
# 139   10'537            Zürich
# 140   10'433         Neuenburg
# 141   10'331      Schaffhausen
# 142   10'323        St. Gallen
# 143   10'313  Basel-Landschaft
# 144   10'281              Genf
# 145   10'232          Obwalden
# 146   10'155  Basel-Landschaft
# 147   10'097              Bern
# 148   10'036               Zug
#
# [149 rows x 8 columns]

# %%
def citynames(elem):
    elem = elem.replace(" 1","").replace(" 2", "").replace(" / 3","")
    return elem
cities = list(t[0][1:][1].apply(citynames))

# %%
cities
# Out:
# ['Zürich',
#  'Genf',
#  'Basel',
#  'Bern',
#  'Lausanne',
#  'Winterthur',
#  'Luzern',
#  'St. Gallen',
#  'Lugano',
#  'Biel/Bienne',
#  'Thun',
#  'Köniz',
#  'La Chaux-de-Fonds',
#  'Freiburg',
#  'Schaffhausen',
#  'Chur',
#  'Vernier',
#  'Neuenburg',
#  'Uster',
#  'Sitten',
#  'Lancy',
#  'Yverdon-les-Bains',
#  'Emmen',
#  'Zug',
#  'Kriens',
#  'Rapperswil-Jona',
#  'Dübendorf',
#  'Dietikon',
#  'Montreux',
#  'Frauenfeld',
#  'Wetzikon',
#  'Wil',
#  'Baar',
#  'Meyrin',
#  'Bulle',
#  'Kreuzlingen',
#  'Wädenswil',
#  'Carouge',
#  'Riehen',
#  'Renens',
#  'Aarau',
#  'Allschwil',
#  'Wettingen',
#  'Horgen',
#  'Nyon',
#  'Vevey',
#  'Bülach',
#  'Reinach',
#  'Baden',
#  'Adliswil',
#  'Volketswil',
#  'Kloten',
#  'Onex',
#  'Bellinzona',
#  'Gossau',
#  'Schlieren',
#  'Thalwil',
#  'Pully',
#  'Glarus Nord 5',
#  'Muttenz',
#  'Regensdorf',
#  'Monthey',
#  'Olten',
#  'Martigny',
#  'Opfikon',
#  'Ostermundigen',
#  'Siders',
#  'Solothurn',
#  'Grenchen',
#  'Val-de-Ruz 6',
#  'Illnau-Effretikon',
#  'Burgdorf',
#  'Freienbach',
#  'Locarno',
#  'Steffisburg',
#  'Pratteln',
#  'Cham',
#  'Herisau',
#  'Morges',
#  'Wohlen',
#  'Wallisellen',
#  'Langenthal',
#  'Binningen',
#  'Einsiedeln',
#  'Mendrisio',
#  'Schwyz',
#  'Lyss',
#  'Arbon',
#  'Thônex',
#  'Liestal',
#  'Stäfa',
#  'Küsnacht',
#  'Horw',
#  'Meilen',
#  'Oftringen',
#  'Versoix',
#  'Richterswil',
#  'Muri bei Bern',
#  'Brig-Glis',
#  'Rheinfelden',
#  'Amriswil',
#  'Ebikon',
#  'Uzwil',
#  'Gland',
#  'Spiez',
#  'Zollikon',
#  'Delsberg',
#  'Glarus',
#  'Küssnacht SZ',
#  'Buchs',
#  'Ecublens',
#  'Villars-sur-Glâne',
#  'Prilly',
#  'Le Grand-Saconnex',
#  'Rüti',
#  'Münchenstein',
#  'Münsingen',
#  'Affoltern am Albis',
#  'Belp',
#  'Worb',
#  'Bassersdorf',
#  'Arth',
#  'Pfäffikon',
#  'Altstätten',
#  'Ittigen',
#  'Zofingen',
#  'La Tour-de-Peilz',
#  'Davos',
#  'Chêne-Bougeries',
#  'Brugg',
#  'Spreitenbach',
#  'Weinfelden',
#  'Veyrier GE',
#  'Oberwil',
#  'Val-de-Travers NE',
#  'Hinwil',
#  'Möhlin',
#  'Romanshorn',
#  'Männedorf',
#  'Le Locle',
#  'Neuhausen am Rheinfall',
#  'Flawil',
#  'Birsfelden',
#  'Plan-les-Ouates',
#  'Sarnen',
#  'Aesch',
#  'Zollikofen',
#  'Risch']

# %% [markdown]
# ## Jetzt ergänzen wir diese Städte

# %%
new_list = []

url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"
query = "query=indische+restaurants+in+"
fields = "fields=formatted_address,name,rating,opening_hours,pagetoken&"
locationbias = "locationbias=point:lat,lng&"
key = "key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&"
pagetoken = ''

for city in cities [:20]: #Nur die ersten 20 Städte!!!!!!!
    result = range(4)
    while len(result) > 3: 
    
        print(len(result))
        api_query = url+query+city+"&"+fields+locationbias+key+pagetoken
        print(api_query)
        time.sleep(2)
        r = requests.get(api_query)
        result = r.json()
        print(len(result))
    
        for elem in result['results']:
            address = elem['formatted_address']
            name = elem['name']
            rating = elem['rating']
            lat = elem['geometry']['location']['lat']
            long = elem['geometry']['location']['lng']
    
            mini_dict = {'Addresse': address, 
                     'Name': name,
                     'Rating': rating,
                     'Lat':lat,
                     'Lng':long}
    
            new_list.append(mini_dict)
        
    
        if len(result) > 3:
            pagetoken = 'pagetoken='+result['next_page_token'] 
        else:
            pagetoken = ''
            break
# Out:
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=indische+restaurants+in+Zürich&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 4
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=indische+restaurants+in+Zürich&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&pagetoken=CuQD1AEAACVlghxk7JZu3-Bs9iBZEg-1bp3cSHCplKoo57M72eO1RdorCY3VREqBhAShnkfqc2ycXYM1Lvhzl6TlWpc4R7joMUp32vYxK1KQhbkcLDwyIO7WLt6QQVG4EVW9tzlW7y_Ybzlevlemm5trqwXtWuxLf6TEMswDgZ44BE2AjKGmiYIhKlNqYRP6ALm9gxouvpx3JzzcGPNOsblXgmaSlv3HxUEVb8kYfJoD2EDV9bN-tYP-azy4_cyPb-UtC-ZzVkTBZhktSHFMQYmNxDrW94-cgcOu3UcVzGjZOTNDcZNrEszhkRqySlzRy-KtuGSEIKRluMBoGChShlr4F9Y9Eyb2yckfAlF9Nbq7RN4g5ezROvzE-31QO1mCaK5hWSnAqnjkrBBMLhGU1cFZWQuSRUrHymY2LmY3HwzevkN8jAmVzCpCSSaGBB68gjNxoMJXTdaTDrUrSyE9mxDVFbK7Az7DuYxit1wnzcKrLp8Z6_5FLUUntji5AG0FC34pzPeGW5O9Mhn2Y80fpcwWZ2hHyE-ts9pJKR1cKTx5cVPpU6J1ujJzqy13leYuBalgByM89nZonhz3EFpsbHXL35j9Shz6alLlJFnZkWEbjbZPU-dFuhwHX6YNaV2vgZ8TFg-tkRIQ9Zl_cVrobqV1Jt3u39qo3BoU6V7U6D2z9j7EgEvtDOuMSHyaZCM
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=indische+restaurants+in+Genf&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 4
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=indische+restaurants+in+Genf&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&pagetoken=CuQD0QEAANwY3-LQ25y_U8EMGhHWqI4CCPHUKXEIqmw9jA3_XEbY4EFLptqWrp0BhNkWJF7Gi_cpzhmB1R-er-ALRrWu-T5W6KHyR8UKEdF1X8yRaXjurr8rhPx2UKNi3tu13-Ky_j3H8pYqWG2bSVO_CFxD92op2cJy7MKj_9wy6SU_iC5wMVzNv0lI2eaUVGUWdbTNd4dRWwB_CmPua4RHHuGmqP9V-V5F91wRG2d8CmutMnUsSWWmiPSV-zAk-l9T0QIwRr9VjSQFYcW5g6HoXKsFQjx_Eqhv3cg1Baf5ZndeEBLAMxjZ76g_a7I7IQBuAk8jDt56vjxvQba-VqW8T2LZs79KRXjC-MBTjnY7mlh6BrUiTYO6Q5NXkX4Xs4e8_DzU_8jFzkyGite43LwQXITnPnKQ91GThU5_409syxt_6t4wshX1DPACvUbBMybP3HyVATS48vfr8Z9AzXDXf5A9Hz1dEHcFR8mN6pTkU43Dy4AlCISIrD0HskQQt5b1-nmO5mF-A1ULjq7kvKlNmgLiRxl71Rke52mMShgbLpsXRi3ZkPbIFM_ZtE1EXfkrlH6HmEIssfT5gioR5ucKSeiuWlu3OoU-x9wGiv6BiEOpTGeVt1ojQ14Uo6k6POJLeuwLnBIQwjrCyTyoA_mauSG6bGiszhoUEHVhGsCkh_s1uKzykAXLHWx9qrI
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=indische+restaurants+in+Basel&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=indische+restaurants+in+Bern&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=indische+restaurants+in+Lausanne&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=indische+restaurants+in+Winterthur&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=indische+restaurants+in+Luzern&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=indische+restaurants+in+St. Gallen&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=indische+restaurants+in+Lugano&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=indische+restaurants+in+Biel/Bienne&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=indische+restaurants+in+Thun&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=indische+restaurants+in+Köniz&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=indische+restaurants+in+La Chaux-de-Fonds&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=indische+restaurants+in+Freiburg&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=indische+restaurants+in+Schaffhausen&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=indische+restaurants+in+Chur&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=indische+restaurants+in+Vernier&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=indische+restaurants+in+Neuenburg&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=indische+restaurants+in+Uster&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 4
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=indische+restaurants+in+Uster&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&pagetoken=CuQD0gEAADXkAa-mPLAgUl3afRFAmJdW21iK4yKWgI7H1w2Cgu4oFSwHCoEu1_ZsEDgYMewSIU_-tnrHBA0TV_HaOViu2OhkfW2Oh9gPgcXhIxqqCAXmAQZ4OsJIxAPzuo1yvv6du62nnEs8NVpshfEX8tFMS0J8VcQxtBu07PYcOci87hDfKVIRiDxLTtjpDHej-GMngLCs-ETu2f50kiNj_jV3wVSdDUKpujaOHGTsO96GIVQW6PZiCN5Qcx_udasXr-3Jsgs0ZsiJu_EMsJv-oac0gnXPjzGWxshpVMMj_kbHMmhDrIRwWNOE7psXI0mjlvrCKUZaahrty42xdUWp1Vqz9ewg3ddaRNo_bWmct29ix-ONa4IUjmu1XKS6UDUgcBLnlDYxBDOG3LuKtS8DTMbBGg4Ie37c-9Ini2dnFZKav0j8-Il6MXZRB5L_JqVJrzRxdQC1WuECHe6sbPus_geY8eW52tAINIjBCK8fAD960VCxMUkBRgMmwg8yDOuLFLdBuKeRvbK-uhLkzuVsURaF_7SIJ2dLmuOpsKpAgQDekmrIS6XQ-JCBzYzrYhZlyffkVlYYQG83n6wl9pnFWkSFsl7FFPFgFydn64Ci-DkRUduJX9-7VWvDxlj3rDljFA6BBxIQs3FQLV36tVM_sBo7AfIU_hoU9RqHgSQ4GdTn_qQ45bVcRzRMZdE
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=indische+restaurants+in+Sitten&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3

# %%
df2 = pd.DataFrame(new_list)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 5 columns):
# Addresse    199 non-null object
# Lat         199 non-null float64
# Lng         199 non-null float64
# Name        199 non-null object
# Rating      199 non-null float64
# dtypes: float64(3), object(2)
# memory usage: 7.9+ KB

# %%
df2 = df2.drop_duplicates()

# %%
df2.to_csv('indischrest_top20cities.csv')

# %%
df2.sort_values(by='Rating', ascending=False)
# Out:
#                                               Addresse        Lat       Lng  \
# 121  9001, Turnerstrasse 2, 9000 St. Gallen, Switze...  47.416170  9.357595
# 91             Moserstrasse 27, 3014 Bern, Switzerland  46.957121  7.452594
# 62    Boulevard Carl-Vogt 62, 1205 Genève, Switzerland  46.197750  6.136010
# 163           Goethestraße 10, 79379 Müllheim, Germany  47.810195  7.627168
# 118  St. Jakob-Strasse 87, 9000 St. Gallen, Switzer...  47.432620  9.382715
# 126         Aarbergstrasse 100, 2502 Biel, Switzerland  47.134194  7.242092
# 30       Beckenhofstrasse 16, 8006 Zürich, Switzerland  47.383323  8.541905
# 76        St. Johanns-Ring 34, 4056 Basel, Switzerland  47.565038  7.578186
# 164          Aathalstrasse 42, 8610 Uster, Switzerland  47.345008  8.731197
# 194    Luppmenstrasse 13, 8320 Fehraltorf, Switzerland  47.388185  8.745068
# 80   60 Avenue Général de Gaulle, 68300 Saint-Louis...  47.581510  7.554603
# 90           Murtenstrasse 131, 3008 Bern, Switzerland  46.949162  7.411204
# 184         Bahnhofstrasse 18, 8610 Uster, Switzerland  47.348676  8.718184
# 42        Rue de Monthoux 58, 1201 Genève, Switzerland  46.211528  6.145726
# 123        Engelgasse 20, 9000 St. Gallen, Switzerland  47.426884  9.374600
# 89          Landorfstrasse 31, 3098 Köniz, Switzerland  46.921421  7.412030
# 135  Rue Daniel-Jeanrichard 14, 2300 La Chaux-de-Fo...  47.101063  6.827891
# 61           125 Rue de Genève, 74240 Gaillard, France  46.191576  6.211151
# 140  Elsässer Str. 71, 79110 Freiburg im Breisgau, ...  48.015549  7.823331
# 165            Loren-Allee 20, 8610 Uster, Switzerland  47.358834  8.709264
# 173       Pfäffikerstrasse 36, 8610 Uster, Switzerland  47.358419  8.729128
# 136  Guntramstraße 22, 79106 Freiburg im Breisgau, ...  47.999654  7.838644
# 170             Poststrasse 6, 8610 Uster, Switzerland  47.349945  8.717804
# 130        Neuenburgstrasse 90, 2505 Biel, Switzerland  47.131734  7.222376
# 146       Unterstadt 7, 8200 Schaffhausen, Switzerland  47.695687  8.639972
# 150             Emserstrasse 4, 7000 Chur, Switzerland  46.845927  9.506398
# 182             Seestrasse 93, 8610 Uster, Switzerland  47.344755  8.704564
# 73             Spalenring 163, 4055 Basel, Switzerland  47.554265  7.576734
# 36          Josefstrasse 146, 8005 Zürich, Switzerland  47.384797  8.527722
# 149         Gäuggelistrasse 60, 7000 Chur, Switzerland  46.850651  9.523965
# ..                                                 ...        ...       ...
# 98         Rue Chaucrau 14, 1003 Lausanne, Switzerland  46.522998  6.631166
# 104     Place de la Gare 9, 1003 Lausanne, Switzerland  46.517111  6.629062
# 166           Ferrachstrasse 1, 8630 Rüti, Switzerland  47.259365  8.851316
# 191          Aathalstrasse 36, 8610 Uster, Switzerland  47.345266  8.730217
# 95   Escaliers du Marché 5, 1003 Lausanne, Switzerland  46.522043  6.633620
# 114        Luzernerstrasse 6, 6030 Ebikon, Switzerland  47.079177  8.336657
# 103        Rue de la Paix 25, 1020 Renens, Switzerland  46.535914  6.591896
# 97    Avenue de la Gare 10, 1003 Lausanne, Switzerland  46.517100  6.635735
# 38           Rue de Berne 11, 1201 Genève, Switzerland  46.209258  6.144821
# 57          Rue des Battoirs, 1205 Genève, Switzerland  46.191742  6.143376
# 46    Rue des Eaux-Vives 102, 1207 Genève, Switzerland  46.205602  6.160973
# 116           Löwengraben 14, 6004 Luzern, Switzerland  47.052920  8.304569
# 22              Mühlegasse 5, 8001 Zürich, Switzerland  47.374439  8.543570
# 111          Zürichstrasse 4, 6004 Luzern, Switzerland  47.056131  8.310607
# 23      Limmattalstrasse 252, 8049 Zürich, Switzerland  47.402748  8.492575
# 37    Stampfenbachstrasse 32, 8006 Zürich, Switzerland  47.379333  8.543476
# 127        Solothurnstrasse 85, 2504 Biel, Switzerland  47.157767  7.273496
# 40   Place de la Navigation 6, 1201 Genève, Switzer...  46.211871  6.150048
# 52       38, Rue de Lausanne, 1201 Genève, Switzerland  46.213221  6.145713
# 60        4, Route de Meyrin, 1202 Genève, Switzerland  46.214171  6.128885
# 197             Poststrasse 2, 8610 Uster, Switzerland  47.350170  8.718293
# 54       Rue de Neuchâtel 37, 1201 Genève, Switzerland  46.211820  6.146354
# 100     Avenue de France 2, 1004 Lausanne, Switzerland  46.524052  6.624509
# 113          Kauffmannweg 20, 6003 Luzern, Switzerland  47.046373  8.306429
# 141  Bertoldstraße 51, 79098 Freiburg im Breisgau, ...  47.995934  7.844149
# 26         Hönggerstrasse 25, 8037 Zürich, Switzerland  47.390972  8.526495
# 35       Hagenholzstrasse 56, 8050 Zürich, Switzerland  47.413469  8.554959
# 63       Rue de Neuchâtel 37, 1201 Genève, Switzerland  46.211812  6.146263
# 92          Länggassstrasse 43, 3012 Bern, Switzerland  46.953925  7.431079
# 34     Stauffacherstrasse 27, 8004 Zürich, Switzerland  47.373013  8.528922
#
#                                       Name  Rating
# 121  Die Fliege Velokurier St. Gallen GmbH     5.0
# 91                         3dosha ayurveda     4.9
# 62                    Restaurant Le Safran     4.9
# 163  Restaurant Bar Lounge Messer & Gradel     4.8
# 118                        Restaurant HOLI     4.8
# 126                          Casa Miracoli     4.7
# 30                            Curry Corner     4.7
# 76                           Johann by Jay     4.7
# 164                    Aladin Pizza Kurier     4.7
# 194                     Restaurant Pumpkin     4.7
# 80                        Maison de l'Inde     4.6
# 90              Indisches Restaurant Kesar     4.6
# 184                                Zum Hut     4.6
# 42                            Indian Plaza     4.6
# 123                      Restaurant Samosa     4.6
# 89                          Indian Kitchen     4.6
# 135                   Restaurant Kashthury     4.6
# 61             Restaurant indien Bollywood     4.6
# 140                                Kashmir     4.6
# 165                                   Flor     4.6
# 173                              BurgerAMT     4.6
# 136                      Indian Curryhouse     4.6
# 170                    Chabis-chäs.ch GmbH     4.6
# 130                      Restaurant Räblus     4.5
# 146                         Toni Take-Away     4.5
# 150                    Restaurant Sommerau     4.5
# 182                            Pizza Forte     4.5
# 73       Bayleaf Gourmet Indian Restaurant     4.5
# 36                          Friends Corner     4.5
# 149                     Restaurant VA BENE     4.5
# ..                                     ...     ...
# 98                  Restaurant Royal India     3.9
# 104                              A l'étage     3.9
# 166                        Restaurant Rani     3.9
# 191                  Tantuni Bistro/ Uster     3.8
# 95                 Laxmi Restaurant Indien     3.8
# 114                               Tandoori     3.8
# 103                                Kashmir     3.8
# 97                                  Shanti     3.8
# 38                       Restaurant Bombay     3.8
# 57                    Zingy Food Chez Neha     3.7
# 46                bombay palace restaurant     3.7
# 116                                 Gandhi     3.7
# 22                              Kormasutra     3.7
# 111                  Kanchi indian cuisine     3.7
# 23                                Maharani     3.7
# 37                          Bombay Karachi     3.7
# 127                               Rotihaus     3.7
# 40                    Restaurant Bollywood     3.7
# 52                        Shahi Restaurant     3.7
# 60                              King Curry     3.6
# 197                             McDonald’s     3.5
# 54                             Café Gandhi     3.4
# 100                            Le Maharaja     3.4
# 113                              Neville's     3.3
# 141                                  Karma     3.2
# 26                              Taj Palace     3.1
# 35                                  Diwali     3.0
# 63               Gandhi Indian Business SA     0.0
# 92                             Singh amrik     0.0
# 34                                  Safran     0.0
#
# [190 rows x 5 columns]

# %%
# städte bereinigen (Code von barnaby):

cityliste = list(df["Stadt"])
addresslist = list(df["Adresse"])

checkedlist = []
for city, address in zip(cityliste, addresslist):
    if city in address:
        checkedlist.append(True)
    else: 
        checkedlist.append(False)
