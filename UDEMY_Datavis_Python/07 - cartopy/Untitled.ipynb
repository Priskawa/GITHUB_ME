# %%
import cartopy.feature as cfeature
import cartopy

fig = plt.figure(figsize=(40, 40))


p = cartopy.crs.Robinson()
ax = plt.axes(projection=p)
ax.set_extent([-23.4953996, 26.2447371, 64.8638882,38.6111709])

# make the map global rather than have it zoom in to
# the extents of any plotted data
# ax.set_global()

# ax.stock_img()
# ax.coastlines()

# // http//www.naturalearthdata.com/download/10m/cultural/ne_10m_admin_0_countries.zip
data = cfeature.NaturalEarthFeature(
    category='cultural',
    name='admin_0_countries',
    scale='10m')

airports = cfeature.NaturalEarthFeature(
    category='cultural',
    name='airports',
    scale='50m')

ax.add_feature(data, edgecolor='gray', facecolor='white')

for airport in airports.geometries():
    ax.plot(airport.x, airport.y, 'o', transform=ccrs.PlateCarree(), color="green", alpha=0.4)

    
ax.plot(-0.08, 51.53, 'o', transform=ccrs.PlateCarree())
ax.plot([-0.08, 132], [51.53, 43.17], transform=ccrs.PlateCarree())
ax.plot([-0.08, 132], [51.53, 43.17], transform=ccrs.Geodetic())

plt.show()
