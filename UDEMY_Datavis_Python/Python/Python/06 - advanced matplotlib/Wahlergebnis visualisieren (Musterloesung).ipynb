# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots()

fig.dpi = 100

seats = [311, 63, 193, 64]
s = sum(seats)
#for seat in seats:
#    s = s + seat
seats.append(s)

ax.pie(seats,
      labels=["Union", "Bündnis 90 / Die Grünen", "SPD", "Die Linke", ""],
      colors=[(0, 0, 0), "#46962b", (1, 0, 0), "#BE3075", (1, 1, 1)])


ax.axis("equal")
ax.legend(loc=(0.1, 0.15))

#ax.set_title("Wahlergebnis")

plt.show()
