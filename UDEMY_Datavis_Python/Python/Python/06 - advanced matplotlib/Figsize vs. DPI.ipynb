# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(5, 3))

fig.dpi = 200

x = [2011, 2013, 2015, 2017]
y = [1050, 1400, 1300, 1600]
y2 = [1100, 1300, 1100, 1400]

ax.scatter(x, y, label="Gewinn x1000", marker="X", s=[16, 200, 16, 16])
ax.plot(x, y2, label="Gewinn 2. Firma x1000", marker="<", linestyle=" ")

ax.legend()
ax.set_title("Punktediagramm")

plt.show()
