# %%
# %matplotlib inline

import matplotlib.pyplot as plt

fig, ax = plt.subplots()

fig.dpi = 1000

x = [1, 2, 3, 4, 5, 6, 7, 8]
y = [2, 4, 5, 3, 4, 5, 7, 2]

ax.plot(x, y)
fig.savefig("Grafik als Bild speichern.png", transparent = True)

plt.show()
