# %% [markdown]
# ## Erste Grafiken zeichnen!
#
# Wir können inzwischen schon ein paar Grafiken zeichnen!

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5, 6, 7, 8]
y = [2, 4, 5, 3, 4, 5, 7, 2]

plt.plot(x, y)
plt.show()

# %%
plt.bar(x, y)
plt.show()
